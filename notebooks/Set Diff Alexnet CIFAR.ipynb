# %% [markdown]
# - what are the nearest neighbors of the additional graph structure induced by the adversary?
#
# - Computing something like an "average" subgraph for a class might be difficult because it is unclear how we deal with conflicting directions on edge weights and how we actually average over all the possible subgraphs examples from various classes could elicit
#     - But this analysis would be fairly interesting. Should think more about how to do this

# %%
import os
import parse
import pickle
import torch
import torch.nn.functional as F
from torchvision import datasets, transforms
import dionysus as dion
import numpy as np
from scipy.spatial.distance import hamming, cosine
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import networkx as nx

from pt_activation.models.alexnet import AlexNet

PERCENTILE = 95

# %load_ext autoreload
# %autoreload 2

# %%
def get_adv_info(filename):
    format_string = 'true-{}_adv-{}_sample-{}.npy'
    parsed = parse.parse(format_string, filename)
    return {'true class':int(parsed[0]), 'adv class':int(parsed[1]), 'sample':int(parsed[2])}

def read_adversaries(loc):
    ret = []
    for f in os.listdir(loc):
        if os.path.isfile(os.path.join(loc,f)) and f.find('.npy') != -1:
            adv = np.load(os.path.join(loc, f))
            info = get_adv_info(f)
            info['adversary'] = adv
            ret.append(info)
    return ret

# %%
adv_directory_loc = '/home/tgebhart/projects/pt_activation/logdir/adversaries/cifar/projected_gradient_descent/alexnet_cifar.pt'
adversaries = read_adversaries(adv_directory_loc)
adversaries = sorted(adversaries,  key=lambda k: k['sample'])

# %%
def get_adv_dists(adversaries, up_to):
    device = torch.device('cpu')
    dists = np.zeros(up_to)
    i = 0
    ims = []
    test_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10(root='../../data/cifar', train=False,
                        download=True, transform = transforms.Compose(
                        [transforms.ToTensor(),
                        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])),
                        batch_size=1, shuffle=False)
    adv_images = np.array([a['adversary'] for a in adversaries])
    with torch.no_grad():
        for data, target in test_loader:
            d = data.numpy()[0].reshape(3*32*32)
            ims.append(d)
            dists[i] = np.linalg.norm(d-adv_images[i].reshape(3*32*32),2)
            i += 1
            if i >= up_to:
                break
            
    return dists, ims

def create_sample_graph(f,tnms,wm):

    subgraphs = {}
    m = dion.homology_persistence(f)
    dgm = dion.init_diagrams(m,f)[0]
    for i,c in enumerate(m):
        if len(c) == 2:
            w = f[i].data
            if (tnms[f[c[0].index][0]],tnms[f[c[1].index][0]]) in wm:
                w = wm[(tnms[f[c[0].index][0]],tnms[f[c[1].index][0]])]
            elif (tnms[f[c[1].index][0]],tnms[f[c[0].index][0]]) in wm:
                w = wm[(tnms[f[c[1].index][0]],tnms[f[c[0].index][0]])]
#                 else:
#                     print((tnms[f[c[0].index][0]],tnms[f[c[1].index][0]]))
#                     raise Exception('NO WM!')
            if False: #tnms[f[c[0].index][0]] in subgraphs:
                subgraphs[tnms[f[c[0].index][0]]].add_edge(tnms[f[c[0].index][0]],tnms[f[c[1].index][0]], weight=w)
            else:
                eaten = False
                for k, v in subgraphs.items():
                    if v.has_node(tnms[f[c[0].index][0]]):
                        if tnms[f[c[1].index][0]] in subgraphs:
                            v.add_node(f[c[1].index][0])
#                                 subgraphs[k] = nx.union(v, subgraphs[tnms[f[c[1].index][0]]])
                        else:
                            v.add_edge(tnms[f[c[0].index][0]], tnms[f[c[1].index][0]], weight=w)
                        eaten = True
                        break
                if not eaten:
                    g = nx.Graph()
                    g.add_edge(tnms[f[c[0].index][0]], tnms[f[c[1].index][0]], weight=w)
                    subgraphs[tnms[f[c[0].index][0]]] = g

    return subgraphs, dgm, create_lifetimes(f,subgraphs,dgm,tnms)

def create_lifetimes(f, subgraphs, dgm, ids):
    lifetimes = {}
    for pt in dgm:
        k = ids[f[pt.data][0]]
        if k in subgraphs.keys():
            if pt.death < float('inf'):
                lifetimes[k] = pt.birth - pt.death
            else:
                lifetimes[k] = pt.birth
    return lifetimes



# In[9]:


def create_subgraphs(model, batch_size, up_to):
    device = torch.device("cpu")
    kwargs = {'num_workers': 1, 'pin_memory': True}
    test_loader = torch.utils.data.DataLoader(
        datasets.CIFAR10(root='../../data/cifar', train=False,
                        download=True, transform = transforms.Compose(
                        [transforms.ToTensor(),
                        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])),
                        batch_size=batch_size, shuffle=False)

    model.eval()
    test_loss = 0
    correct = 0
    t = 0
    res_df = []
    subgraphs = []
    diagrams = []
    lifetimes = []
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output, hiddens = model(data, hiddens=True)
            test_loss = F.nll_loss(output, target).item() # sum up batch loss
            pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

            for s in range(data.shape[0]):
                this_hiddens = [hiddens[i][s] for i in range(len(hiddens))]
                print('Filtration: {}'.format(s+t))
                f, nm, wm = model.compute_induced_filtration(data[s], this_hiddens, percentile=PERCENTILE, return_nm=True, absolute_value=True)
                tnm = {v: k for k, v in nm.items()}
                sg, dg, lifetime = create_sample_graph(f, tnm, wm)
                row = {'loss':test_loss, 'class':target.cpu().numpy()[s], 'prediction':pred.cpu().numpy()[s][0]}
                res_df.append(row)
                subgraphs.append(sg)
                diagrams.append(dg)
                lifetimes.append(lifetime)

            t += batch_size
            if t >= up_to:
                break

    return pd.DataFrame(res_df), subgraphs, diagrams, lifetimes


def create_adversary_subgraphs(model, batch_size, up_to, adversaries):
    device = torch.device("cpu")
    adv_images = torch.tensor(np.array([a['adversary'] for a in adversaries]))
    adv_labels = torch.tensor(np.array([a['true class'] for a in adversaries]))
    adv_samples = [a['sample'] for a in adversaries]

    print(adv_images.shape, adv_labels.shape)

    advs = torch.utils.data.TensorDataset(adv_images, adv_labels)
    test_loader = torch.utils.data.DataLoader(advs, batch_size=batch_size, shuffle=False)

    model.eval()
    test_loss = 0
    correct = 0
    t = 0
    res_df = []
    subgraphs = []
    diagrams = []
    lifetimes = []
    with torch.no_grad():

        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output, hiddens = model(data, hiddens=True)
            test_loss = F.nll_loss(output, target).item() # sum up batch loss
            pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            for s in range(data.shape[0]):
                this_hiddens = [hiddens[i][s] for i in range(len(hiddens))]
                print('Filtration: {}'.format(s+t))
                f, nm, wm = model.compute_induced_filtration(data[s], this_hiddens, percentile=PERCENTILE, return_nm=True, absolute_value=True)
                tnm = {v: k for k, v in nm.items()}
                sg, dg, lifetime = create_sample_graph(f, tnm, wm)
                row = {'loss':test_loss, 'class':target.cpu().numpy()[s], 'prediction':pred.cpu().numpy()[s][0]}
                res_df.append(row)
                subgraphs.append(sg)
                diagrams.append(dg)
                lifetimes.append(lifetime)

            t += (batch_size)
            if t >= up_to:
                break

    return pd.DataFrame(res_df), subgraphs, diagrams, lifetimes

def create_moved_subgraphs(model, ims, labels, devs, batch_size, up_to, times=1):
    device = torch.device("cpu")

    nims = []
    for i in range(len(ims)):
#         print('finding alteration number', i)
        im = ims[i]
        dev = devs[i]
        delim = np.zeros(im.shape, dtype=im.dtype)
        sigma = 0
        while np.linalg.norm(im+delim - im) < dev:
            sigma += 0.00001
            delim = np.random.normal(scale=sigma, size=im.shape)
        nims.append((im+delim).reshape(3,32,32))
    tims = torch.FloatTensor(nims)
    tlabels = torch.tensor(np.array(labels))
    dataset = torch.utils.data.TensorDataset(tims, tlabels)
    test_loader = torch.utils.data.DataLoader(dataset, batch_size=batch_size, shuffle=False)
    
    model.eval()
    test_loss = 0
    correct = 0
    t = 0
    res_df = []
    subgraphs = []
    diagrams = []
    lifetimes = []
#     with torch.no_grad():

#         for data, target in test_loader:
#             data, target = data.to(device), target.to(device)
#             output, hiddens = model(data, hiddens=True)
#             test_loss = F.nll_loss(output, target).item() # sum up batch loss
#             pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
#             correct += pred.eq(target.view_as(pred)).sum().item()
#             for s in range(data.shape[0]):
#                 this_hiddens = [hiddens[i][s] for i in range(len(hiddens))]
#                 print('Filtration: {}'.format(s+t))
#                 f, nm, wm = model.compute_induced_filtration(data[s], this_hiddens, percentile=PERCENTILE, return_nm=True, absolute_value=True)
#                 tnm = {v: k for k, v in nm.items()}
#                 sg, dg, lifetime = create_sample_graph(f, tnm, wm)
#                 row = {'loss':test_loss, 'class':target.cpu().numpy()[s], 'prediction':pred.cpu().numpy()[s][0]}
#                 res_df.append(row)
#                 subgraphs.append(sg)
#                 diagrams.append(dg)
#                 lifetimes.append(lifetime)

#             t += (batch_size)
#             if t >= up_to:
#                 break

    return pd.DataFrame(res_df), subgraphs, diagrams, lifetimes, nims

# %%
model_location = '/home/tgebhart/projects/pt_activation/logdir/models/alexnet_cifar.pt'
model = AlexNet()
model.load_state_dict(torch.load(model_location, map_location='cpu'))

# %%
res_df, sample_graphs, diagrams, lifetimes = create_subgraphs(model, 50, 50)
# Out:
# Files already downloaded and verified
# Filtration: 0
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.14800382 1.14800382 0.21248299 0.63744897 0.05179652 0.04195053
#  0.07266609 0.50866264 0.0211885  0.00245262 0.00823752]
# creating filtration object...
# filtration size 964937
# Sorting filtration...
# Filtration: 1
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.2545993  1.2545993  0.27385739 0.82157216 0.08019178 0.06561237
#  0.13780279 0.96461955 0.04181296 0.00489045 0.01693928]
# creating filtration object...
# filtration size 938213
# Sorting filtration...
# Filtration: 2
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.93128154 0.93128154 0.14685917 0.44057752 0.04380217 0.03300174
#  0.07351834 0.51462838 0.02149863 0.00253355 0.00861808]
# creating filtration object...
# filtration size 953205
# Sorting filtration...
# Filtration: 3
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.13490859 1.13490859 0.30801598 0.92404794 0.07198274 0.04799967
#  0.09123281 0.63862967 0.02912247 0.00345849 0.01213513]
# creating filtration object...
# filtration size 957923
# Sorting filtration...
# Filtration: 4
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.80329283 0.80329283 0.15567792 0.46703375 0.05614104 0.0575822
#  0.13814511 0.96701575 0.04022538 0.00459321 0.01697768]
# creating filtration object...
# filtration size 918708
# Sorting filtration...
# Filtration: 5
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.56540906 0.56540906 0.14890986 0.44672959 0.05823515 0.05276984
#  0.11286301 0.79004106 0.03550232 0.00395102 0.01416614]
# creating filtration object...
# filtration size 914979
# Sorting filtration...
# Filtration: 6
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.54238021 1.54238021 0.30593673 0.9178102  0.0751153  0.04743837
#  0.08342536 0.58397751 0.02829851 0.00315085 0.01042919]
# creating filtration object...
# filtration size 971701
# Sorting filtration...
# Filtration: 7
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.73912607 0.73912607 0.20969109 0.62907327 0.05344297 0.03169533
#  0.05779172 0.40454204 0.01725786 0.00202863 0.00705996]
# creating filtration object...
# filtration size 934698
# Sorting filtration...
# Filtration: 8
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.85960889 0.85960889 0.10187358 0.30562073 0.03534052 0.02616522
#  0.05490607 0.3843425  0.01656027 0.00195848 0.00690509]
# creating filtration object...
# filtration size 981674
# Sorting filtration...
# Filtration: 9
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.15422019 1.15422019 0.17734115 0.53202345 0.06100742 0.04858458
#  0.11352693 0.79468853 0.03396323 0.0038542  0.0123407 ]
# creating filtration object...
# filtration size 937588
# Sorting filtration...
# Filtration: 10
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.02748838 1.02748838 0.14924902 0.44774707 0.05126228 0.04190818
#  0.09158871 0.64112096 0.02976477 0.00345016 0.0120463 ]
# creating filtration object...
# filtration size 944673
# Sorting filtration...
# Filtration: 11
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.03691059 1.03691059 0.21425704 0.64277113 0.08317618 0.07249573
#  0.14649035 1.02543246 0.04501544 0.00505968 0.016339  ]
# creating filtration object...
# filtration size 920516
# Sorting filtration...
# Filtration: 12
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.95629658 0.95629658 0.17934793 0.53804379 0.04870917 0.03540713
#  0.07486589 0.52406123 0.02328035 0.00271443 0.01041352]
# creating filtration object...
# filtration size 955027
# Sorting filtration...
# Filtration: 13
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.64680693 1.64680693 0.32161858 0.96485574 0.09582918 0.07921471
#  0.18762244 1.31335707 0.0612201  0.0072369  0.0258895 ]
# creating filtration object...
# filtration size 947147
# Sorting filtration...
# Filtration: 14
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.11321256 1.11321256 0.19803986 0.59411959 0.06729733 0.05558546
#  0.12580219 0.88061536 0.04172337 0.00494713 0.01655854]
# creating filtration object...
# filtration size 936934
# Sorting filtration...
# Filtration: 15
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.26663491 1.26663491 0.21770947 0.6531284  0.07718374 0.05779593
#  0.11033094 0.77231661 0.03556836 0.00400886 0.01401481]
# creating filtration object...
# filtration size 931203
# Sorting filtration...
# Filtration: 16
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.36361638 1.36361638 0.25399466 0.76198399 0.07417735 0.04855469
#  0.08090741 0.56635185 0.02655389 0.00325365 0.01186824]
# creating filtration object...
# filtration size 957017
# Sorting filtration...
# Filtration: 17
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.03331646 1.03331646 0.1896449  0.5689347  0.05308369 0.0410742
#  0.10059358 0.70415508 0.03185762 0.00357286 0.01210626]
# creating filtration object...
# filtration size 948707
# Sorting filtration...
# Filtration: 18
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.94275694 0.94275694 0.21288403 0.6386521  0.06461222 0.05146772
#  0.11342145 0.79395016 0.03328034 0.00380867 0.01324073]
# creating filtration object...
# filtration size 926406
# Sorting filtration...
# Filtration: 19
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.93049473 0.93049473 0.22055942 0.66167827 0.0685446  0.05049448
#  0.11125427 0.77877991 0.03456958 0.00371221 0.01322773]
# creating filtration object...
# filtration size 919533
# Sorting filtration...
# Filtration: 20
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.21885061 1.21885061 0.25078955 0.75236864 0.07546006 0.05571973
#  0.119258   0.83480597 0.03925112 0.00445111 0.0149909 ]
# creating filtration object...
# filtration size 948834
# Sorting filtration...
# Filtration: 21
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [2.06466198 2.06466198 0.48451802 1.45355407 0.15121647 0.1055685
#  0.21253596 1.48775173 0.0612833  0.00739283 0.02743269]
# creating filtration object...
# filtration size 948300
# Sorting filtration...
# Filtration: 22
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.06272084 1.06272084 0.2176213  0.65286389 0.04207146 0.02201806
#  0.03340165 0.23381156 0.00989955 0.00124284 0.00478335]
# creating filtration object...
# filtration size 969857
# Sorting filtration...
# Filtration: 23
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.17566827 1.17566827 0.27045388 0.81136165 0.08806117 0.08892746
#  0.2257957  1.5805699  0.07246318 0.0081445  0.02655345]
# creating filtration object...
# filtration size 916927
# Sorting filtration...
# Filtration: 24
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.91176702 0.91176702 0.17379251 0.52137754 0.04832241 0.03871556
#  0.09589869 0.67129082 0.03130551 0.00371171 0.01481063]
# creating filtration object...
# filtration size 936095
# Sorting filtration...
# Filtration: 25
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.00447324 1.00447324 0.21879033 0.65637099 0.07119053 0.0434114
#  0.0762792  0.53395439 0.02311472 0.00259894 0.00967984]
# creating filtration object...
# filtration size 932917
# Sorting filtration...
# Filtration: 26
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.79583466 0.79583466 0.15986663 0.47959989 0.04826798 0.03876584
#  0.09384639 0.65692476 0.02870092 0.0031343  0.01009735]
# creating filtration object...
# filtration size 993055
# Sorting filtration...
# Filtration: 27
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.91159829 0.91159829 0.19093206 0.57279618 0.0473093  0.02872035
#  0.04871635 0.34101446 0.01642238 0.00184111 0.00679244]
# creating filtration object...
# filtration size 951828
# Sorting filtration...
# Filtration: 28
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.26520547 1.26520547 0.19693347 0.5908004  0.05918841 0.04730212
#  0.10905084 0.76335586 0.03664497 0.00406773 0.01295843]
# creating filtration object...
# filtration size 934403
# Sorting filtration...
# Filtration: 29
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.57568537 0.57568537 0.2041178  0.6123534  0.06266196 0.06364827
#  0.15015788 1.05110514 0.04492412 0.00522425 0.01941334]
# creating filtration object...
# filtration size 912098
# Sorting filtration...
# Filtration: 30
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.45027268 0.45027268 0.10842427 0.32527281 0.03412285 0.02499583
#  0.05039617 0.3527732  0.01650138 0.00180007 0.00632282]
# creating filtration object...
# filtration size 927412
# Sorting filtration...
# Filtration: 31
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.6202621  0.6202621  0.16952807 0.50858421 0.05305294 0.04328509
#  0.08810929 0.61676506 0.02705381 0.00312135 0.01198678]
# creating filtration object...
# filtration size 930035
# Sorting filtration...
# Filtration: 32
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.71790616 0.71790616 0.13457865 0.40373596 0.04562067 0.03009205
#  0.05667776 0.3967443  0.0180104  0.00212781 0.00755672]
# creating filtration object...
# filtration size 930548
# Sorting filtration...
# Filtration: 33
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.801064   0.801064   0.14339665 0.43018994 0.04550245 0.03208452
#  0.07203136 0.50421949 0.02039788 0.00239514 0.00918798]
# creating filtration object...
# filtration size 964741
# Sorting filtration...
# Filtration: 34
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.97889197 0.97889197 0.18197007 0.54591021 0.06447669 0.06141992
#  0.13903544 0.97324811 0.04320041 0.00501296 0.01638886]
# creating filtration object...
# filtration size 934617
# Sorting filtration...
# Filtration: 35
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.10384297 1.10384297 0.16075224 0.48225672 0.06914137 0.0521416
#  0.08953611 0.62675276 0.03098692 0.00328712 0.01140085]
# creating filtration object...
# filtration size 963394
# Sorting filtration...
# Filtration: 36
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.65512905 0.65512905 0.1744553  0.52336591 0.0516304  0.05547777
#  0.15012865 1.05090054 0.04555289 0.00527036 0.01889655]
# creating filtration object...
# filtration size 921672
# Sorting filtration...
# Filtration: 37
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.48931444 1.48931444 0.26606411 0.79819234 0.08938159 0.06974046
#  0.15232865 1.06630054 0.05204844 0.00582753 0.01833995]
# creating filtration object...
# filtration size 939483
# Sorting filtration...
# Filtration: 38
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.15841892 1.15841892 0.26094151 0.78282453 0.12977265 0.13184742
#  0.27369151 1.91584059 0.0855538  0.00962298 0.03083546]
# creating filtration object...
# filtration size 916223
# Sorting filtration...
# Filtration: 39
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.08696368 1.08696368 0.19651734 0.58955202 0.06362202 0.06945893
#  0.15428552 1.07999864 0.04403367 0.00541198 0.01785794]
# creating filtration object...
# filtration size 934737
# Sorting filtration...
# Filtration: 40
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.35076174 1.35076174 0.2567012  0.77010359 0.0764263  0.05685965
#  0.11375987 0.79631906 0.03733253 0.00425852 0.0161047 ]
# creating filtration object...
# filtration size 933874
# Sorting filtration...
# Filtration: 41
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.64062548 0.64062548 0.17085629 0.51256886 0.0549921  0.04297521
#  0.08245124 0.57715871 0.02454194 0.00287401 0.00958817]
# creating filtration object...
# filtration size 911994
# Sorting filtration...
# Filtration: 42
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.01020887 1.01020887 0.21662131 0.64986393 0.06180439 0.05441261
#  0.11004677 0.77032736 0.03272759 0.00393605 0.01311418]
# creating filtration object...
# filtration size 960269
# Sorting filtration...
# Filtration: 43
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.74288595 0.74288595 0.18542393 0.5562718  0.06959148 0.06284405
#  0.11960822 0.83725754 0.03774077 0.00432124 0.01531924]
# creating filtration object...
# filtration size 942246
# Sorting filtration...
# Filtration: 44
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.93275082 1.93275082 0.49115248 1.47345743 0.08223617 0.05479826
#  0.08415877 0.58911139 0.02449519 0.00291357 0.0101779 ]
# creating filtration object...
# filtration size 996053
# Sorting filtration...
# Filtration: 45
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.36112821 1.36112821 0.19294844 0.57884533 0.08140737 0.07003685
#  0.15987887 1.11915212 0.04888845 0.00556999 0.01796995]
# creating filtration object...
# filtration size 942355
# Sorting filtration...
# Filtration: 46
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.75845559 0.75845559 0.21095219 0.63285658 0.05245549 0.04408263
#  0.08991289 0.6293902  0.0253503  0.00297616 0.0105093 ]
# creating filtration object...
# filtration size 943319
# Sorting filtration...
# Filtration: 47
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.06001222 1.06001222 0.13506547 0.40519642 0.05119244 0.03394159
#  0.06439644 0.45077507 0.02085485 0.00232123 0.00777655]
# creating filtration object...
# filtration size 976257
# Sorting filtration...
# Filtration: 48
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.72422183 0.72422183 0.19570456 0.58711367 0.06562218 0.08190755
#  0.21864678 1.53052745 0.06750171 0.00811669 0.02898068]
# creating filtration object...
# filtration size 909139
# Sorting filtration...
# Filtration: 49
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.51983707 0.51983707 0.16111678 0.48335033 0.04695782 0.03874434
#  0.07549986 0.52849902 0.02393306 0.00279618 0.00989324]
# creating filtration object...
# filtration size 910408
# Sorting filtration...

# %%
adv_df, adv_sample_graphs, adv_diagrams, adv_lifetimes = create_adversary_subgraphs(model, 50, 50, adversaries)
# Out:
# torch.Size([1000, 3, 32, 32]) torch.Size([1000])
# Filtration: 0
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.14652041 1.14652041 0.21121516 0.63364548 0.0504319  0.03976583
#  0.06931565 0.48520955 0.02034622 0.00237988 0.0080904 ]
# creating filtration object...
# filtration size 968904
# Sorting filtration...
# Filtration: 1
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.24620956 1.24620956 0.25233279 0.75699838 0.07714471 0.06426681
#  0.13633553 0.95434873 0.04342009 0.00502333 0.01704348]
# creating filtration object...
# filtration size 936478
# Sorting filtration...
# Filtration: 2
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.93128154 0.93128154 0.14685917 0.44057752 0.04380217 0.03300174
#  0.07351834 0.51462838 0.02149863 0.00253355 0.00861808]
# creating filtration object...
# filtration size 953205
# Sorting filtration...
# Filtration: 3
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.1346769  1.1346769  0.29849913 0.89549739 0.07200706 0.04635655
#  0.08921812 0.62452681 0.02787426 0.00322741 0.01103785]
# creating filtration object...
# filtration size 956054
# Sorting filtration...
# Filtration: 4
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.79990092 0.79990092 0.15261139 0.45783417 0.05488023 0.05498126
#  0.12771113 0.89397794 0.03634715 0.00420524 0.01593753]
# creating filtration object...
# filtration size 920618
# Sorting filtration...
# Filtration: 5
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.56701328 0.56701328 0.14630381 0.43891144 0.05465975 0.04804148
#  0.10749784 0.75248491 0.03263621 0.0036169  0.01336578]
# creating filtration object...
# filtration size 913748
# Sorting filtration...
# Filtration: 6
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.54194465 1.54194465 0.30592472 0.91777415 0.07488852 0.0475001
#  0.08368272 0.58577903 0.02809914 0.003125   0.01039225]
# creating filtration object...
# filtration size 972450
# Sorting filtration...
# Filtration: 7
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.73654911 0.73654911 0.21027152 0.63081456 0.05202375 0.03001481
#  0.05077547 0.35542828 0.01576389 0.00186474 0.00683605]
# creating filtration object...
# filtration size 937784
# Sorting filtration...
# Filtration: 8
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.85958095 0.85958095 0.10212164 0.30636491 0.0354104  0.02626988
#  0.05431241 0.38018687 0.01652077 0.00195834 0.00695636]
# creating filtration object...
# filtration size 980970
# Sorting filtration...
# Filtration: 9
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.15973854 1.15973854 0.17652511 0.52957533 0.0605495  0.04772582
#  0.10943394 0.76603761 0.03281152 0.0036639  0.01155563]
# creating filtration object...
# filtration size 939944
# Sorting filtration...
# Filtration: 10
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.0275006  1.0275006  0.14933563 0.44800689 0.05101189 0.04179292
#  0.09152474 0.64067317 0.0298228  0.00345674 0.01206705]
# creating filtration object...
# filtration size 945176
# Sorting filtration...
# Filtration: 11
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.03000021 1.03000021 0.21732298 0.65196894 0.08173817 0.06550129
#  0.11998699 0.83990892 0.03689593 0.00418262 0.0137316 ]
# creating filtration object...
# filtration size 923956
# Sorting filtration...
# Filtration: 12
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.95826955 0.95826955 0.18418131 0.55254393 0.04695794 0.03330568
#  0.06862511 0.4803758  0.02094182 0.00241551 0.00936118]
# creating filtration object...
# filtration size 959710
# Sorting filtration...
# Filtration: 13
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.64273083 1.64273083 0.3157639  0.94729169 0.09594249 0.07779509
#  0.18077665 1.26543657 0.05849566 0.00692749 0.0249381 ]
# creating filtration object...
# filtration size 946859
# Sorting filtration...
# Filtration: 14
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.10440293 1.10440293 0.20366487 0.61099462 0.06517103 0.05643543
#  0.12172822 0.85209756 0.04028866 0.00458768 0.01512499]
# creating filtration object...
# filtration size 939128
# Sorting filtration...
# Filtration: 15
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.26663491 1.26663491 0.21770947 0.6531284  0.07718374 0.05779593
#  0.11033094 0.77231661 0.03556836 0.00400886 0.01401481]
# creating filtration object...
# filtration size 931203
# Sorting filtration...
# Filtration: 16
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.36637717 1.36637717 0.25032595 0.75097784 0.07321757 0.04657474
#  0.07396967 0.51778768 0.02341279 0.00276555 0.00954654]
# creating filtration object...
# filtration size 961178
# Sorting filtration...
# Filtration: 17
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.02874738 1.02874738 0.18664485 0.55993454 0.05176159 0.03978901
#  0.08984312 0.62890187 0.02905648 0.00319777 0.01075831]
# creating filtration object...
# filtration size 950749
# Sorting filtration...
# Filtration: 18
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.93513647 0.93513647 0.20426758 0.61280273 0.06176753 0.04901236
#  0.10421116 0.72947809 0.03112486 0.00358579 0.01227223]
# creating filtration object...
# filtration size 930635
# Sorting filtration...
# Filtration: 19
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.93078579 0.93078579 0.21997649 0.65992947 0.06753465 0.04928944
#  0.10831625 0.75821372 0.03351827 0.00360671 0.01292809]
# creating filtration object...
# filtration size 920439
# Sorting filtration...
# Filtration: 20
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.21525952 1.21525952 0.25183493 0.75550479 0.07363252 0.05450054
#  0.11403947 0.79827626 0.03767597 0.00425931 0.01434113]
# creating filtration object...
# filtration size 952084
# Sorting filtration...
# Filtration: 21
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [2.05735457 2.05735457 0.47917774 1.43753323 0.15155147 0.10546769
#  0.21335332 1.49347321 0.06197421 0.00745998 0.02784779]
# creating filtration object...
# filtration size 947314
# Sorting filtration...
# Filtration: 22
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.06272084 1.06272084 0.2176213  0.65286389 0.04207146 0.02201806
#  0.03340165 0.23381156 0.00989955 0.00124284 0.00478335]
# creating filtration object...
# filtration size 969857
# Sorting filtration...
# Filtration: 23
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.16214535 1.16214535 0.28757098 0.86271294 0.07595001 0.06749741
#  0.15937039 1.11559275 0.05383621 0.00614822 0.01962561]
# creating filtration object...
# filtration size 925578
# Sorting filtration...
# Filtration: 24
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.91176702 0.91176702 0.17379251 0.52137754 0.04832241 0.03871556
#  0.09589869 0.67129082 0.03130551 0.00371171 0.01481063]
# creating filtration object...
# filtration size 936095
# Sorting filtration...
# Filtration: 25
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.99650972 0.99650972 0.21703626 0.65110879 0.06933836 0.04284948
#  0.07671022 0.53697155 0.02428576 0.00273523 0.0100697 ]
# creating filtration object...
# filtration size 930103
# Sorting filtration...
# Filtration: 26
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.79511109 0.79511109 0.15795451 0.47386354 0.04794405 0.03859563
#  0.09319059 0.65233414 0.02889936 0.00315651 0.01012259]
# creating filtration object...
# filtration size 994701
# Sorting filtration...
# Filtration: 27
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.91159829 0.91159829 0.19093206 0.57279618 0.0473093  0.02872035
#  0.04871635 0.34101446 0.01642238 0.00184111 0.00679244]
# creating filtration object...
# filtration size 951828
# Sorting filtration...
# Filtration: 28
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.26863578 1.26863578 0.19844808 0.59534425 0.05779366 0.04582151
#  0.10474711 0.73322977 0.03629198 0.00403137 0.01278463]
# creating filtration object...
# filtration size 936986
# Sorting filtration...
# Filtration: 29
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.56967038 0.56967038 0.20567869 0.61703606 0.06308894 0.06330972
#  0.14991515 1.04940605 0.04473058 0.00518952 0.01956536]
# creating filtration object...
# filtration size 912053
# Sorting filtration...
# Filtration: 30
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.44972542 0.44972542 0.10817076 0.32451229 0.03329337 0.02390787
#  0.04708462 0.32959231 0.01510437 0.00163547 0.00570429]
# creating filtration object...
# filtration size 929621
# Sorting filtration...
# Filtration: 31
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.61127125 0.61127125 0.17191848 0.51575545 0.0523341  0.04010946
#  0.07812586 0.54688099 0.02463449 0.00281306 0.01075248]
# creating filtration object...
# filtration size 932135
# Sorting filtration...
# Filtration: 32
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.71786235 0.71786235 0.13575362 0.40726086 0.04468408 0.02835312
#  0.0511759  0.35823132 0.01675794 0.00195379 0.00671897]
# creating filtration object...
# filtration size 932866
# Sorting filtration...
# Filtration: 33
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.79825224 0.79825224 0.14301168 0.42903503 0.04547598 0.03231752
#  0.07169448 0.50186133 0.02036643 0.00237286 0.00903042]
# creating filtration object...
# filtration size 965435
# Sorting filtration...
# Filtration: 34
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.97980262 0.97980262 0.18606812 0.55820436 0.06480919 0.05504639
#  0.11079418 0.77555928 0.03598207 0.00416934 0.01374635]
# creating filtration object...
# filtration size 934707
# Sorting filtration...
# Filtration: 35
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.10384297 1.10384297 0.16075224 0.48225672 0.06914137 0.0521416
#  0.08953611 0.62675276 0.03098692 0.00328712 0.01140085]
# creating filtration object...
# filtration size 963394
# Sorting filtration...
# Filtration: 36
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.65512905 0.65512905 0.1744553  0.52336591 0.0516304  0.05547777
#  0.15012865 1.05090054 0.04555289 0.00527036 0.01889655]
# creating filtration object...
# filtration size 921672
# Sorting filtration...
# Filtration: 37
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.48675871 1.48675871 0.26539868 0.79619605 0.08968775 0.06927522
#  0.14950903 1.04656323 0.05123279 0.00571455 0.01799828]
# creating filtration object...
# filtration size 938377
# Sorting filtration...
# Filtration: 38
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.14919347 1.14919347 0.28064882 0.84194646 0.13148785 0.12891713
#  0.28800301 2.01602104 0.08938369 0.01033105 0.03251123]
# creating filtration object...
# filtration size 918184
# Sorting filtration...
# Filtration: 39
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.09942707 1.09942707 0.18452236 0.55356709 0.06147089 0.05367228
#  0.11430596 0.8001417  0.03362776 0.00393883 0.01255185]
# creating filtration object...
# filtration size 934656
# Sorting filtration...
# Filtration: 40
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.35943484 1.35943484 0.26250667 0.78752002 0.07531565 0.0530939
#  0.10075902 0.70531317 0.03286914 0.00370896 0.01365195]
# creating filtration object...
# filtration size 935853
# Sorting filtration...
# Filtration: 41
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.6375099  0.6375099  0.16008405 0.48025216 0.04906054 0.03201218
#  0.04812522 0.33687652 0.01529286 0.00180348 0.00617614]
# creating filtration object...
# filtration size 918122
# Sorting filtration...
# Filtration: 42
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.01410133 1.01410133 0.2172267  0.65168009 0.06107178 0.05051222
#  0.10078878 0.70552145 0.03061246 0.00362882 0.0118735 ]
# creating filtration object...
# filtration size 960687
# Sorting filtration...
# Filtration: 43
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.73933718 0.73933718 0.18147847 0.54443541 0.06680435 0.05670564
#  0.1038511  0.72695772 0.03200369 0.00374495 0.01391698]
# creating filtration object...
# filtration size 946670
# Sorting filtration...
# Filtration: 44
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.91496497 1.91496497 0.49305411 1.47916234 0.08189125 0.05451591
#  0.08510696 0.59574873 0.02483141 0.0029217  0.01011823]
# creating filtration object...
# filtration size 998765
# Sorting filtration...
# Filtration: 45
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.35948855 1.35948855 0.19631813 0.58895438 0.07791913 0.06418692
#  0.14602173 1.02215208 0.04450353 0.00507619 0.01658053]
# creating filtration object...
# filtration size 942335
# Sorting filtration...
# Filtration: 46
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.75845559 0.75845559 0.21095219 0.63285658 0.05245549 0.04408263
#  0.08991289 0.6293902  0.0253503  0.00297616 0.0105093 ]
# creating filtration object...
# filtration size 943319
# Sorting filtration...
# Filtration: 47
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [1.06001222 1.06001222 0.13506547 0.40519642 0.05119244 0.03394159
#  0.06439644 0.45077507 0.02085485 0.00232123 0.00777655]
# creating filtration object...
# filtration size 976257
# Sorting filtration...
# Filtration: 48
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.73115559 0.73115559 0.19337686 0.58013058 0.06416442 0.07586908
#  0.19969005 1.39783032 0.06062912 0.00732635 0.02700086]
# creating filtration object...
# filtration size 910128
# Sorting filtration...
# Filtration: 49
# cpu count: 4
# layer: 0
# layer: 1
# layer: 2
# layer: 3
# layer: 4
# layer: 5
# layer: 6
# layer: 7
# layer: 8
# layer: 9
# layer: 10
# percentiles: [0.5178827  0.5178827  0.1606203  0.48186091 0.04608605 0.03645939
#  0.07051225 0.49358573 0.02250071 0.00264095 0.00966581]
# creating filtration object...
# filtration size 910334
# Sorting filtration...

# %%
dists, ims = get_adv_dists(adversaries, 50)
# Out:
# Files already downloaded and verified

# %%
moved_df, moved_sample_graphs, moved_diagrams, moved_lifetimes, moved_ims = create_moved_subgraphs(model, ims, res_df['class'], dists, 50, 50, times=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-37-6ebb75682af1> in <module>
# ----> 1 moved_df, moved_sample_graphs, moved_diagrams, moved_lifetimes, moved_ims = create_moved_subgraphs(model, ims, res_df['class'], dists, 50, 50, times=1)
#
# <ipython-input-36-cf8f6c0a9b53> in create_moved_subgraphs(model, ims, labels, devs, batch_size, up_to, times)
#     175         while np.linalg.norm(im+delim - im) < dev:
#     176             sigma += 0.00001
# --> 177             delim = np.random.normal(scale=sigma, size=im.shape)
#     178         nims.append((im+delim).reshape(3,32,32))
#     179     tims = torch.FloatTensor(nims)
#
# KeyboardInterrupt:

# %%
_, _, _, _, moved_ims = create_moved_subgraphs(model, ims, res_df['class'], dists, 50, 50, times=1)

# %%
print('Moved Accuracy:', moved_df[moved_df['prediction'] == moved_df['class']].shape[0]/moved_df.shape[0])
print('Actual Accuracy:', res_df[res_df['prediction'] == res_df['class']].shape[0]/res_df.shape[0])
# Out:
# Moved Accuracy: 0.82
# Actual Accuracy: 0.82

# %%
res_df.head()
# Out:
#    class     loss  prediction
# 0      3 -8.79896           3
# 1      8 -8.79896           8
# 2      8 -8.79896           1
# 3      0 -8.79896           0
# 4      6 -8.79896           6

# %%
import pickle
with open(os.path.join(adv_directory_loc, 'moving_adv_samples.pkl'), 'wb') as f:
    pickle.dump(adv_sample_graphs, f)
with open(os.path.join(adv_directory_loc, 'moving_samples.pkl'), 'wb') as f:
    pickle.dump(sample_graphs, f)
with open(os.path.join(adv_directory_loc, 'moving_moved_samples.pkl'), 'wb') as f:
    pickle.dump(moved_sample_graphs, f)

# %%
res_df.head(10)
# Out:
#    class     loss  prediction
# 0      3 -8.79896           3
# 1      8 -8.79896           8
# 2      8 -8.79896           1
# 3      0 -8.79896           0
# 4      6 -8.79896           6
# 5      6 -8.79896           6
# 6      1 -8.79896           1
# 7      6 -8.79896           6
# 8      3 -8.79896           3
# 9      1 -8.79896           1

# %%
goi = 1

# %%
# plt.subplot(131).imshow(ims[goi].reshape(3,32,32).T, interpolation='nearest')
# plt.subplot(132).imshow(adv_ims[goi].reshape(3,32,32).T, interpolation='nearest')
# plt.subplot(133).imshow(moved_ims[goi].reshape(3,32,32).T, interpolation='nearest')

# %%
dion.plot.plot_diagram(diagrams[goi])

# %%
dion.plot.plot_diagram(adv_diagrams[goi])

# %%
dion.plot.plot_diagram(moved_diagrams[goi])

# %%
lifetimes[goi]
# Out:
# {(8, 0, 100): 1.7015348672866821,
#  (8, 0, 78): 1.5120328962802887,
#  (8, 0, 136): 1.3436363115906715,
#  (8, 0, 153): 1.3288786262273788,
#  (8, 0, 25): 1.242962285876274,
#  (8, 0, 145): 1.2233067899942398,
#  (8, 0, 57): 1.1877081543207169,
#  (8, 0, 150): 1.1380736529827118,
#  (8, 0, 175): 1.1002157032489777,
#  (8, 0, 182): 1.0834249332547188,
#  (8, 0, 149): 1.0527952313423157,
#  (7, 34, 2): 1.0142979249358177,
#  (8, 0, 186): 0.9926889389753342,
#  (7, 67, 2): 0.9545869827270508,
#  (7, 9, 3): 0.9586096927523613,
#  (7, 79, 3): 0.9521820768713951,
#  (8, 0, 187): 0.9537128433585167,
#  (2, 10, 109): 0.3737204968929291,
#  (2, 10, 110): 0.04582494497299194,
#  (2, 10, 130): 0.3737204968929291,
#  (2, 10, 131): 0.04582494497299194,
#  (2, 10, 108): 0.03712204098701477,
#  (2, 10, 129): 0.03712204098701477,
#  (2, 15, 114): 0.315717488527298,
#  (2, 15, 115): 0.315717488527298,
#  (2, 15, 135): 0.315717488527298,
#  (2, 15, 136): 0.315717488527298,
#  (4, 105, 34): 0.3080865740776062,
#  (2, 31, 214): 0.3071865439414978,
#  (2, 31, 215): 0.0016408562660217285,
#  (2, 31, 235): 0.3071865439414978,
#  (2, 31, 236): 0.0016408562660217285,
#  (2, 15, 116): 0.3027702867984772,
#  (2, 15, 137): 0.3027702867984772,
#  (2, 10, 53): 0.298780232667923,
#  (2, 10, 54): 0.014036595821380615,
#  (2, 10, 74): 0.298780232667923,
#  (2, 10, 75): 0.014036595821380615,
#  (4, 105, 33): 0.06963691115379333,
#  (2, 31, 256): 0.2925789952278137,
#  (2, 31, 257): 0.0015628039836883545,
#  (2, 31, 212): 0.0013341903686523438,
#  (2, 31, 233): 0.0013341903686523438,
#  (2, 10, 52): 0.001962989568710327,
#  (2, 10, 73): 0.001962989568710327,
#  (2, 61, 177): 0.284217894077301,
#  (2, 61, 178): 0.284217894077301,
#  (2, 61, 198): 0.284217894077301,
#  (2, 61, 199): 0.284217894077301,
#  (2, 10, 55): 0.28209972381591797,
#  (2, 10, 76): 0.28209972381591797,
#  (2, 31, 216): 0.0015043020248413086,
#  (2, 31, 237): 0.0015043020248413086,
#  (2, 61, 179): 0.27953219413757324,
#  (2, 61, 200): 0.27953219413757324,
#  (2, 10, 51): 0.2759318947792053,
#  (4, 147, 36): 0.0009372010827064514,
#  (4, 150, 25): 0.0031540095806121826,
#  (4, 96, 43): 0.003566563129425049,
#  (4, 51, 61): 0.00667930394411087,
#  (4, 77, 63): 0.012002728879451752,
#  (4, 5, 16): 0.0023693665862083435,
#  (4, 176, 18): 0.00319749116897583,
#  (4, 167, 4): 0.016552507877349854,
#  (4, 100, 2): 0.004820466041564941,
#  (4, 185, 40): 0.0020028874278068542,
#  (4, 123, 1): 0.0005097463726997375,
#  (4, 167, 35): 0.0015568584203720093,
#  (4, 43, 56): 0.10113286226987839,
#  (4, 112, 59): 0.0012918561697006226,
#  (4, 15, 30): 0.004107289016246796,
#  (4, 115, 8): 0.006755344569683075,
#  (4, 2, 22): 0.00518517941236496,
#  (4, 93, 30): 0.0015087500214576721,
#  (4, 150, 20): 0.013254128396511078,
#  (4, 68, 3): 0.009938463568687439,
#  (4, 93, 29): 0.0006146803498268127,
#  (4, 100, 1): 0.004507429897785187,
#  (4, 15, 38): 0.0065898597240448,
#  (4, 77, 3): 0.0028885379433631897,
#  (4, 105, 19): 0.0015181079506874084,
#  (4, 115, 59): 0.00154847651720047,
#  (4, 159, 17): 0.00835399329662323,
#  (4, 15, 31): 0.003860883414745331,
#  (4, 150, 19): 0.012568697333335876,
#  (4, 100, 3): 0.0030522942543029785,
#  (4, 20, 44): 0.005324184894561768,
#  (4, 84, 53): 0.0019735023379325867,
#  (4, 15, 24): 0.006722688674926758,
#  (4, 123, 0): 0.0004637613892555237,
#  (10, 0, 95): 0.006953857839107513,
#  (4, 20, 43): 0.00525163859128952,
#  (10, 0, 2093): 0.016741856932640076,
#  (4, 99, 39): 0.0068377479910850525,
#  (4, 147, 6): 0.0017109960317611694,
#  (4, 147, 33): 0.0028673484921455383,
#  (4, 5, 17): 0.001979611814022064,
#  (4, 176, 3): 0.0026787742972373962,
#  (4, 147, 13): 0.0028511807322502136,
#  (4, 77, 59): 0.08732376247644424,
#  (4, 7, 18): 0.00397917628288269,
#  (4, 47, 15): 0.08585582673549652,
#  (4, 20, 42): 0.004828944802284241,
#  (4, 52, 40): 0.0014836639165878296,
#  (4, 159, 16): 0.002546548843383789,
#  (10, 0, 1429): 0.014545045793056488,
#  (4, 100, 4): 0.002724260091781616,
#  (4, 188, 58): 0.08359958231449127,
#  (4, 15, 35): 0.0008596032857894897,
#  (4, 147, 5): 0.08128594607114792,
#  (4, 47, 14): 0.08011671900749207,
#  (10, 0, 193): 0.006241023540496826}

# %%
with open(os.path.join(adv_directory_loc, 'adv_lifetimes.pkl'), 'wb') as f:
    pickle.dump(adv_lifetimes, f)
with open(os.path.join(adv_directory_loc, 'moving_lifetimes.pkl'), 'wb') as f:
    pickle.dump(lifetimes, f)
with open(os.path.join(adv_directory_loc, 'moving_moved_lifetimes.pkl'), 'wb') as f:
    pickle.dump(moved_lifetimes, f)

# %%
def hamming_distance(g1, g2, ret_labels=False):
    nodeset = set(list(g1.nodes) + list(g2.nodes))
    g1_vec = np.zeros((len(nodeset)))
    g2_vec = np.zeros((len(nodeset)))
    nodesetlist = list(nodeset)
    for i in range(len(nodesetlist)):
        node = nodesetlist[i]
        if node in g1.nodes:
            g1_vec[i] = 1.0
        if node in g2.nodes:
            g2_vec[i] = 1.0
    if ret_labels:
        return hamming(g1_vec, g2_vec), nodesetlist
    else:
        return hamming(g1_vec, g2_vec)
    
def edge_hamming_distance(g1, g2, ret_labels=False):
    edgeset = set(list(g1.edges) + list(g2.edges))
    g1_vec = np.zeros((len(edgeset)))
    g2_vec = np.zeros((len(edgeset)))
    edgesetlist = list(edgeset)
    for i in range(len(edgesetlist)):
        edge = edgesetlist[i]
        if edge in g1.edges:
            g1_vec[i] = 1.0
        if edge in g2.edges:
            g2_vec[i] = 1.0
    if ret_labels:
        return hamming(g1_vec, g2_vec), edgesetlist
    else:
        return hamming(g1_vec, g2_vec)
    
def lifetime_weighted_edge_distance(subgraphs1,subgraphs2,lifetimes1,lifetimes2,ret_labels=False):
    edges1 = {}
    edges2 = {}
    sg1keys = list(subgraphs1.keys())
    sg2keys = list(subgraphs2.keys())
    lifetimes1 = list(lifetimes1.values())
    lifetimes2 = list(lifetimes2.values())
    ml1 = max(lifetimes1)
    ml2 = max(lifetimes2)
    for i in range(len(sg1keys)):
        g = subgraphs1[sg1keys[i]]
        for e in g.edges:
            edges1[e] = lifetimes1[i]/ml1
    for i in range(len(sg2keys)):
        g = subgraphs2[sg2keys[i]]
        for e in g.edges:
            edges2[e] = lifetimes2[i]/ml2
    edgeset = set(list(edges1.keys()) + list(edges2.keys()))
    g1_vec = np.zeros((len(edgeset)))
    g2_vec = np.zeros((len(edgeset)))
    edgesetlist = list(edgeset)
    for i in range(len(edgesetlist)):
        edge = edgesetlist[i]
        if edge in edges1:
            g1_vec[i] += edges1[edge]
        if edge in edges2:
            g2_vec[i] += edges2[edge]
    if ret_labels:
        return cosine(g1_vec, g2_vec), edgesetlist
    else:
        return cosine(g1_vec, g2_vec)
    
def weighted_edge_distance(g1, g2, ret_labels=False):
    edgeset = set(list(g1.edges) + list(g2.edges))
    g1_vec = np.zeros((len(edgeset)))
    g2_vec = np.zeros((len(edgeset)))
    edgesetlist = list(edgeset)
    for i in range(len(edgesetlist)):
        edge = edgesetlist[i]
        if edge in g1.edges:
            g1_vec[i] = g1[edge[0]][edge[1]]['weight']
        if edge in g2.edges:
            g2_vec[i] = g2[edge[0]][edge[1]]['weight']
    if ret_labels:
        return cosine(g1_vec, g2_vec), edgesetlist
    else:
        return cosine(g1_vec, g2_vec)
    
def total_edge_weights(graphs):
    emap = {}
    for g in graphs:
        for e in g.edges:
            if e in emap:
                emap[e] += g[e[0]][e[1]]['weight']
            else:
                emap[e] = g[e[0]][e[1]]['weight']
    return emap

def count_nodes(graphs):
    nmap = {}
    for g in graphs:
        for n in g.nodes:
            if n in nmap:
                nmap[n] += 1.0
            else:
                nm[2] = 1.0
    return nmap

# %%
sorted_res_df = res_df.sort_values(by=['prediction'])
sorted_res_df.head()
# Out:
#     class     loss  prediction
# 21      0 -8.79896           0
# 44      0 -8.79896           0
# 3       0 -8.79896           0
# 22      4 -8.79896           0
# 10      0 -8.79896           0

# %%
# adv_sample_graphs = pickle.load(open(os.path.join(adv_directory_loc, 'moving_adv_samples.pkl'), 'rb'))
# sample_graphs = pickle.load(open(os.path.join(adv_directory_loc, 'moving_samples.pkl'), 'rb'))
# moved_sample_graphs = pickle.load(open(os.path.join(adv_directory_loc, 'moving_moved_samples.pkl'), 'rb'))

# %%
# adv_sample_graphs = pickle.load(open(os.path.join(adv_directory_loc, 'moving_adv_samples.pkl'), 'rb'))

# %%
# comb_sim_mat = np.zeros((len(combs),len(adv_combs)))
# for i in range(len(combs)):
#     g = combs[i]
#     for j in range(len(adv_combs)):
#         ag = adv_combs[j]
#         comb_sim_mat[i,j] = 1 - weighted_edge_distance(g,ag)

# comb_sim_mat = np.zeros((len(sample_graphs), len(adv_sample_graphs)))
# for i in range(len(sample_graphs)):
#     for j in range(len(adv_sample_graphs)):
#         comb_sim_mat[i,j] = 1 - lifetime_weighted_edge_distance(sample_graphs[i],adv_sample_graphs[j],lifetimes[i],adv_lifetimes[j])

adv_sim_mat = np.zeros((len(sample_graphs), len(adv_sample_graphs)))
for i in range(len(sample_graphs)):
    for j in range(len(adv_sample_graphs)):
        adv_sim_mat[i,j] = 1 - lifetime_weighted_edge_distance(sample_graphs[i],adv_sample_graphs[j],lifetimes[i],adv_lifetimes[j])

# %%
ax = sns.heatmap(adv_sim_mat, xticklabels=5, yticklabels=5)
plt.yticks(rotation=0)
plt.xticks(rotation=0)
plt.tick_params(axis='y',labelsize=5)
plt.tick_params(axis='x',labelsize=5)
plt.ylabel('Unaltered Subgraphs')
plt.xlabel('Adversarial Subgraphs')
plt.savefig('/home/tgebhart/projects/pt_activation/logdir/vis/alexnet_cifar/adv_comb_heatmap.png', format='png', dpi=500)

# %%
moved_sim_mat = np.zeros((len(sample_graphs), len(moved_sample_graphs)))
for i in range(len(sample_graphs)):
    for j in range(len(moved_sample_graphs)):
        moved_sim_mat[i,j] = 1 - lifetime_weighted_edge_distance(sample_graphs[i],moved_sample_graphs[j],lifetimes[i],moved_lifetimes[j])

# %%
ax = sns.heatmap(moved_sim_mat, xticklabels=5, yticklabels=5)
plt.yticks(rotation=0)
plt.xticks(rotation=0)
plt.tick_params(axis='y',labelsize=5)
plt.tick_params(axis='x',labelsize=5)
plt.ylabel('Unaltered Subgraphs')
plt.xlabel('Adversarial Subgraphs')
plt.savefig('/home/tgebhart/projects/pt_activation/logdir/vis/alexnet_cifar/moved_comb_heatmap.png', format='png', dpi=500)

# %%
moved_dists = np.array([get_adv_dists(ims[i], moved_ims[i]) for i in range(res_df.shape[0])])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-7d8d862967d3> in <module>
# ----> 1 moved_dists = np.array([get_adv_dists(ims[i], moved_ims[i]) for i in range(res_df.shape[0])])
#
# <ipython-input-39-7d8d862967d3> in <listcomp>(.0)
# ----> 1 moved_dists = np.array([get_adv_dists(ims[i], moved_ims[i]) for i in range(res_df.shape[0])])
#
# <ipython-input-36-cf8f6c0a9b53> in get_adv_dists(adversaries, up_to)
#       1 def get_adv_dists(adversaries, up_to):
#       2     device = torch.device('cpu')
# ----> 3     dists = np.zeros(up_to)
#       4     i = 0
#       5     ims = []
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
bins = 25
plt.hist(np.diagonal(adv_sim_mat), bins, alpha=0.5, label='Adversaries', color='r')
plt.hist(np.diagonal(moved_sim_mat), bins, alpha=0.5, label='Randomly Perturbed', color='b')
plt.xlabel('Similarity to Unaltered Subgraph')
plt.ylabel('Frequency')
plt.legend()

# %%
fig, ax = plt.subplots()
differs = np.diagonal(adv_sim_mat) - np.diagonal(moved_sim_mat)
colors = ['b' if differs[i] > 0 else 'r' for i in range(len(sample_graphs))]
ax.scatter(np.diagonal(adv_sim_mat), np.diagonal(moved_sim_mat), c=colors)
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)
plt.xlabel('Adversarial Perturbation Similarity')
plt.ylabel('Random Perturbation Similarity')
# Out:
# Text(0, 0.5, 'Random Perturbation Similarity')

# %%
# bins = 25
# plt.hist(dists, bins, alpha=0.5, label='Adversaries', color='r')
# plt.hist(moved_dists, bins, alpha=0.5, label='Random Pertubation', color='b')
# plt.xlabel('Distance to Unaltered Image')
# plt.ylabel('Frequency')
# plt.legend()

# %%
def compute_num_generators(g):
    return len(g)
def compute_num_edges(g):
    num_edges = 0
    for sgk in g:
        num_edges += len(g[sgk].edges())
    return num_edges

# %%
num_generators = [compute_num_generators(g) for g in sample_graphs]
adv_num_generators = [compute_num_generators(g) for g in adv_sample_graphs]
moved_num_generators = [compute_num_generators(g) for g in moved_sample_graphs]

# %%
bins = 25
plt.hist(num_generators, bins, alpha=0.5, label='Unaltered', color='g')
plt.hist(adv_num_generators, bins, alpha=0.5, label='Adversaries', color='r')
plt.hist(moved_num_generators, bins, alpha=0.5, label='Random Pertubation', color='b')
plt.xlabel('Number of Generators')
plt.ylabel('Frequency')
plt.legend()

# %%
num_edges = np.array([compute_num_edges(g) for g in sample_graphs])
adv_num_edges = np.array([compute_num_edges(g) for g in adv_sample_graphs])
moved_num_edges = np.array([compute_num_edges(g) for g in moved_sample_graphs])

# %%
bins = 10
plt.hist(num_edges, bins, alpha=0.5, label='Unaltered', color='g')
plt.hist(adv_num_edges, bins, alpha=0.5, label='Adversaries', color='r')
plt.hist(moved_num_edges, bins, alpha=0.5, label='Random Pertubation', color='b')
plt.xlabel('Number of Edges')
plt.ylabel('Frequency')
plt.legend()

# %%
fig, ax = plt.subplots()
differs = adv_num_edges - num_edges
colors = ['b' if differs[i] > 0 else 'r' for i in range(moved_num_edges.shape[0])]
ax.scatter(moved_num_edges, adv_num_edges, c=colors)
lims = [
    np.min([ax.get_xlim(), ax.get_ylim()]),  # min of both axes
    np.max([ax.get_xlim(), ax.get_ylim()]),  # max of both axes
]

# now plot both limits against eachother
ax.plot(lims, lims, 'k-', alpha=0.75, zorder=0)
ax.set_aspect('equal')
ax.set_xlim(lims)
ax.set_ylim(lims)
# Out:
# (9944.440143369175, 32748.559856630818)

# %%
differs[differs >= 0].shape[0]/num_edges.shape[0]
# Out:
# 0.78

# %% [markdown]
# - Compute the set differences for each adversary and compare these set differences to each of the unaltered images like we did for the adv_sim_mat above.
# - Sort this similarity matrix by the _predicted_ class of the adversary. We would expect to see some sort of relationship emerge if these subgraphs were targeting class-specific information within the persistent subgraphs
# - Compute these differences based on the composed graphs like in `lifetime_weighted_edge_distance()`

# %%
def set_difference(subgraphs1, subgraphs2):
    sg1keys = list(subgraphs1.keys())
    sg2keys = list(subgraphs2.keys())
    remove_edges = []
    edges2 = []
    for i in range(len(sg1keys)):
        g = subgraphs1[sg1keys[i]]
        remove_edges += list(g.edges)
    for i in range(len(sg2keys)):
        g = subgraphs2[sg2keys[i]]
        edges2 += list(g.edges)
    keep_edges = set(edges2).difference(set(remove_edges))
    ret_graph = nx.compose_all([subgraphs2[k] for k in sg2keys])
    rge = list(ret_graph.edges())
    ret_graph.remove_edges_from(e for e in rge if e not in keep_edges)
    return ret_graph

# %%
sorted_res_df = res_df.sort_values(by=['prediction'])
sorted_adv_df = adv_df.sort_values(by=['prediction'])

# %%
sorted_adv_df.head()
# Out:
#     class      loss  prediction
# 22      4 -6.739214           0
# 18      8 -6.739214           0
# 41      6 -6.739214           0
# 40      4 -6.739214           0
# 1       8 -6.739214           1

# %%
adv_differences = [set_difference(sample_graphs[i], adv_sample_graphs[i]) for i in range(len(sample_graphs))]

combs = []
for i in range(len(sample_graphs)):
    combs.append(nx.compose_all([sample_graphs[i][k] for k in sample_graphs[i]]))

# %%
diff_sim_mat = np.zeros((len(combs),len(adv_differences)))
for i in range(len(combs)):
    g = combs[i]
    for j in range(len(adv_differences)):
        ag = adv_differences[j]
        diff_sim_mat[i,j] = 1 - weighted_edge_distance(g,ag)
# Out:
# /home/tgebhart/.local/lib/python3.6/site-packages/scipy/spatial/distance.py:702: RuntimeWarning: invalid value encountered in double_scalars
#   dist = 1.0 - uv / np.sqrt(uu * vv)

# %%
sorted_diff_sim_mat = np.empty(diff_sim_mat.shape)
sidxs = list(sorted_adv_df.index)
# aidxs = list(sorted_adv_df.index)
aidxs = sidxs
for i in range(len(sidxs)):
    for j in range(len(aidxs)):
        sorted_diff_sim_mat[i,j] = diff_sim_mat[sidxs[i],aidxs[j]]
        
sdsmdf = pd.DataFrame(sorted_diff_sim_mat, columns=sorted_adv_df['prediction'], index=sorted_res_df['prediction'])

# %%
ax = sns.heatmap(diff_sim_mat, xticklabels=5, yticklabels=5)
plt.yticks(rotation=0)
plt.xticks(rotation=0)
plt.tick_params(axis='y',labelsize=5)
plt.tick_params(axis='x',labelsize=5)
plt.ylabel('Unaltered Subgraphs')
plt.xlabel('Adversarial Subgraphs')
plt.savefig('/home/tgebhart/projects/pt_activation/logdir/vis/alexnet_cifar/adv_diff_heatmap.png', format='png', dpi=500)
