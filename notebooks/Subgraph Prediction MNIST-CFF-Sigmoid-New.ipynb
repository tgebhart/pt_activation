# %% [markdown]
# Can we back into the same adversary prediction abilities using only the sorted edge weights? I.e. if we just look at the top n edges in the filtration, is this good enough? Or do we actually use persistent homology effectively?

# %%
import os
import parse
import pickle
import copy
import math

import torch
import torch.nn.functional as F
from torchvision import datasets, transforms
from torch.utils.data import Dataset, DataLoader
import dionysus as dion
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.spatial.distance import hamming, cosine
from sklearn import svm
from sklearn.model_selection import cross_val_score
import sklearn
import networkx as nx
import seaborn as sns

from pt_activation.models.cff_sigmoid import CFF

# %load_ext autoreload
# %autoreload 2

# %%
COLORS = ['#12355b', '#ff6978']
EDGE_COLOR = '#272d2d'
PLT_LABELS = ['Unaltered', 'Adversarial']

# %%
def get_adv_info(filename):
    format_string = 'true-{}_adv-{}_sample-{}.npy'
    parsed = parse.parse(format_string, filename)
    return {'true class':int(parsed[0]), 'adv class':int(parsed[1]), 'sample':int(parsed[2])}

def read_adversaries(loc):
    ret = []
    for f in os.listdir(loc):
        if os.path.isfile(os.path.join(loc,f)) and f.find('.npy') != -1:
            adv = np.load(os.path.join(loc, f))
            info = get_adv_info(f)
            info['adversary'] = adv
            ret.append(info)
    return ret

# %%
adv_directory_loc = '/home/tgebhart/projects/pt_activation/logdir/adversaries/mnist/carliniwagnerl2/cff_sigmoid.pt'
adversaries = read_adversaries(adv_directory_loc)
adversaries = sorted(adversaries,  key=lambda k: k['sample'])

# %%
def create_sample_graph(f,tnms,wm):

    subgraphs = {}
    m = dion.homology_persistence(f)
    dgm = dion.init_diagrams(m,f)[0]
    for i,c in enumerate(m):
        if len(c) == 2:
            w = f[i].data
            if (tnms[f[c[0].index][0]],tnms[f[c[1].index][0]]) in wm:
                w = wm[(tnms[f[c[0].index][0]],tnms[f[c[1].index][0]])]
            elif (tnms[f[c[1].index][0]],tnms[f[c[0].index][0]]) in wm:
                w = wm[(tnms[f[c[1].index][0]],tnms[f[c[0].index][0]])]
#                 else:
#                     print((tnms[f[c[0].index][0]],tnms[f[c[1].index][0]]))
#                     raise Exception('NO WM!')
            if False: #tnms[f[c[0].index][0]] in subgraphs:
                subgraphs[tnms[f[c[0].index][0]]].add_edge(tnms[f[c[0].index][0]],tnms[f[c[1].index][0]], weight=w)
            else:
                eaten = False
                for k, v in subgraphs.items():
                    if v.has_node(tnms[f[c[0].index][0]]):
                        if tnms[f[c[1].index][0]] in subgraphs:
                            v.add_node(f[c[1].index][0])
#                                 subgraphs[k] = nx.union(v, subgraphs[tnms[f[c[1].index][0]]])
                        else:
                            v.add_edge(tnms[f[c[0].index][0]], tnms[f[c[1].index][0]], weight=w)
                        eaten = True
                        break
                if not eaten:
                    g = nx.Graph()
                    g.add_edge(tnms[f[c[0].index][0]], tnms[f[c[1].index][0]], weight=w)
                    subgraphs[tnms[f[c[0].index][0]]] = g
    
    return subgraphs, dgm, create_lifetimes(f,subgraphs,dgm,tnms)

def create_lifetimes(f, subgraphs, dgm, ids):
    lifetimes = {}
    for pt in dgm:
        k = ids[f[pt.data][0]] 
        if k in subgraphs.keys():
            if pt.death < float('inf'):
                lifetimes[k] = pt.birth - pt.death
            else:
                lifetimes[k] = pt.birth
    return lifetimes

# %%
def create_subgraphs(model, batch_size, up_to):
    device = torch.device("cpu")
    kwargs = {'num_workers': 1, 'pin_memory': True}
    test_loader = torch.utils.data.DataLoader(
        datasets.MNIST('../data', train=False, download=True, transform=transforms.Compose([
                           transforms.ToTensor(),
#                            transforms.Normalize((0.1307,), (0.3081,))
                       ])), batch_size=batch_size, shuffle=False, **kwargs)

    model.eval()
    test_loss = 0
    correct = 0
    t = 0
    res_df = []
    subgraphs = []
    diagrams = []
    lifetimes = []
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output, hiddens = model(data, hiddens=True)
            test_loss = F.nll_loss(output, target).item() # sum up batch loss
            pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

            for s in range(data.shape[0]):
                this_hiddens = [hiddens[0][s], hiddens[1][s], hiddens[2][s]]
                print('Filtration: {}'.format(s+t))
                f, nm, wm = model.compute_dynamic_filtration2(data[s], this_hiddens, percentile=0, return_nm=True, absolute_value=True, input_layer=False)
                tnm = {v: k for k, v in nm.items()}
                sg, dg, lifetime = create_sample_graph(f, tnm, wm)
                row = {'loss':test_loss, 'class':target.cpu().numpy()[s], 'prediction':pred.cpu().numpy()[s][0]}
                res_df.append(row)
                subgraphs.append(sg)
                diagrams.append(dg)
                lifetimes.append(lifetime)

            t += batch_size
            if t >= up_to:
                break

    return pd.DataFrame(res_df), subgraphs, diagrams, lifetimes


def create_adversary_subgraphs(model, batch_size, up_to, adversaries):
    device = torch.device("cpu")
    adv_images = torch.tensor(np.array([a['adversary'] for a in adversaries]))
    adv_labels = torch.tensor(np.array([a['true class'] for a in adversaries]))
    adv_samples = [a['sample'] for a in adversaries]
    
    print(adv_images.shape, adv_labels.shape)
    
    advs = torch.utils.data.TensorDataset(adv_images, adv_labels)
    test_loader = torch.utils.data.DataLoader(advs, batch_size=batch_size, shuffle=False)
    
    model.eval()
    test_loss = 0
    correct = 0
    t = 0
    res_df = []
    subgraphs = []
    diagrams = []
    lifetimes = []
    with torch.no_grad():
        
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output, hiddens = model(data, hiddens=True)
            test_loss = F.nll_loss(output, target).item() # sum up batch loss
            pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            for s in range(data.shape[0]):
                this_hiddens = [hiddens[0][s], hiddens[1][s], hiddens[2][s]]
                print('Filtration: {}'.format(s+t))
                f, nm, wm = model.compute_dynamic_filtration2(data[s], this_hiddens, percentile=0, return_nm=True, absolute_value=True, input_layer=False)
                tnm = {v: k for k, v in nm.items()}
                sg, dg, lifetime = create_sample_graph(f, tnm, wm)
                row = {'loss':test_loss, 'class':target.cpu().numpy()[s], 'prediction':pred.cpu().numpy()[s][0]}
                res_df.append(row)
                subgraphs.append(sg)
                diagrams.append(dg)
                lifetimes.append(lifetime)

            t += (batch_size)
            if t >= up_to:
                break

    return pd.DataFrame(res_df), subgraphs, diagrams, lifetimes

# %%
model_location = '/home/tgebhart/projects/pt_activation/logdir/models/mnist/cff_sigmoid.pt'
model = CFF()
model.load_state_dict(torch.load(model_location))

# %%
res_df, sample_graphs, dgms, lifetimes = create_subgraphs(model, 1, 2000)
# Out:
# Filtration: 0
# filtration size 77275
# Filtration: 1
# filtration size 142673
# Filtration: 2
# filtration size 17357
# Filtration: 3
# filtration size 100185
# Filtration: 4
# filtration size 59808
# Filtration: 5
# filtration size 12070
# Filtration: 6
# filtration size 103369
# Filtration: 7
# filtration size 86325
# Filtration: 8
# filtration size 38112
# Filtration: 9
# filtration size 23850
# Filtration: 10
# filtration size 126050
# Filtration: 11
# filtration size 74575
# Filtration: 12
# filtration size 23435
# Filtration: 13
# filtration size 74521
# Filtration: 14
# filtration size 77261
# Filtration: 15
# filtration size 19130
# Filtration: 16
# filtration size 36701
# Filtration: 17
# filtration size 119416
# Filtration: 18
# filtration size 83625
# Filtration: 19
# filtration size 30624
# Filtration: 20
# filtration size 63195
# Filtration: 21
# filtration size 106579
# Filtration: 22
# filtration size 117739
# Filtration: 23
# filtration size 18964
# Filtration: 24
# filtration size 52214
# Filtration: 25
# filtration size 131342
# Filtration: 26
# filtration size 94605
# Filtration: 27
# filtration size 15201
# Filtration: 28
# filtration size 116091
# Filtration: 29
# filtration size 57034
# Filtration: 30
# filtration size 79607
# Filtration: 31
# filtration size 67976
# Filtration: 32
# filtration size 65927
# Filtration: 33
# filtration size 138891
# Filtration: 34
# filtration size 79134
# Filtration: 35
# filtration size 107699
# Filtration: 36
# filtration size 88181
# Filtration: 37
# filtration size 47395
# Filtration: 38
# filtration size 132961
# Filtration: 39
# filtration size 100814
# Filtration: 40
# filtration size 17730
# Filtration: 41
# filtration size 76976
# Filtration: 42
# filtration size 40057
# Filtration: 43
# filtration size 67154
# Filtration: 44
# filtration size 50711
# Filtration: 45
# filtration size 95500
# Filtration: 46
# filtration size 91292
# Filtration: 47
# filtration size 59052
# Filtration: 48
# filtration size 93544
# Filtration: 49
# filtration size 125522
# Filtration: 50
# filtration size 55471
# Filtration: 51
# filtration size 99995
# Filtration: 52
# filtration size 74511
# Filtration: 53
# filtration size 31964
# Filtration: 54
# filtration size 134238
# Filtration: 55
# filtration size 85075
# Filtration: 56
# filtration size 96164
# Filtration: 57
# filtration size 18323
# Filtration: 58
# filtration size 21908
# Filtration: 59
# filtration size 12794
# Filtration: 60
# filtration size 124365
# Filtration: 61
# filtration size 59820
# Filtration: 62
# filtration size 18574
# Filtration: 63
# filtration size 77549
# Filtration: 64
# filtration size 83216
# Filtration: 65
# filtration size 20813
# Filtration: 66
# filtration size 110551
# Filtration: 67
# filtration size 39655
# Filtration: 68
# filtration size 48715
# Filtration: 69
# filtration size 122138
# Filtration: 70
# filtration size 97061
# Filtration: 71
# filtration size 132567
# Filtration: 72
# filtration size 130601
# Filtration: 73
# filtration size 30658
# Filtration: 74
# filtration size 63287
# Filtration: 75
# filtration size 45362
# Filtration: 76
# filtration size 94684
# Filtration: 77
# filtration size 56631
# Filtration: 78
# filtration size 8420
# Filtration: 79
# filtration size 44728
# Filtration: 80
# filtration size 88427
# Filtration: 81
# filtration size 95446
# Filtration: 82
# filtration size 131178
# Filtration: 83
# filtration size 112469
# Filtration: 84
# filtration size 42230
# Filtration: 85
# filtration size 118623
# Filtration: 86
# filtration size 77796
# Filtration: 87
# filtration size 107366
# Filtration: 88
# filtration size 132841
# Filtration: 89
# filtration size 39035
# Filtration: 90
# filtration size 93767
# Filtration: 91
# filtration size 121522
# Filtration: 92
# filtration size 7690
# Filtration: 93
# filtration size 58582
# Filtration: 94
# filtration size 120796
# Filtration: 95
# filtration size 45907
# Filtration: 96
# filtration size 90432
# Filtration: 97
# filtration size 12849
# Filtration: 98
# filtration size 121582
# Filtration: 99
# filtration size 82330
# Filtration: 100
# filtration size 61385
# Filtration: 101
# filtration size 65371
# Filtration: 102
# filtration size 105462
# Filtration: 103
# filtration size 99365
# Filtration: 104
# filtration size 59551
# Filtration: 105
# filtration size 24636
# Filtration: 106
# filtration size 133169
# Filtration: 107
# filtration size 17532
# Filtration: 108
# filtration size 103158
# Filtration: 109
# filtration size 15192
# Filtration: 110
# filtration size 61616
# Filtration: 111
# filtration size 36454
# Filtration: 112
# filtration size 30478
# Filtration: 113
# filtration size 45318
# Filtration: 114
# filtration size 28535
# Filtration: 115
# filtration size 15776
# Filtration: 116
# filtration size 32594
# Filtration: 117
# filtration size 41928
# Filtration: 118
# filtration size 14263
# Filtration: 119
# filtration size 10750
# Filtration: 120
# filtration size 76784
# Filtration: 121
# filtration size 19861
# Filtration: 122
# filtration size 124625
# Filtration: 123
# filtration size 44801
# Filtration: 124
# filtration size 98616
# Filtration: 125
# filtration size 80757
# Filtration: 126
# filtration size 144450
# Filtration: 127
# filtration size 7940
# Filtration: 128
# filtration size 34259
# Filtration: 129
# filtration size 7977
# Filtration: 130
# filtration size 95919
# Filtration: 131
# filtration size 105022
# Filtration: 132
# filtration size 120116
# Filtration: 133
# filtration size 88920
# Filtration: 134
# filtration size 28324
# Filtration: 135
# filtration size 102148
# Filtration: 136
# filtration size 95748
# Filtration: 137
# filtration size 67216
# Filtration: 138
# filtration size 90495
# Filtration: 139
# filtration size 28614
# Filtration: 140
# filtration size 57103
# Filtration: 141
# filtration size 111424
# Filtration: 142
# filtration size 133146
# Filtration: 143
# filtration size 57725
# Filtration: 144
# filtration size 14909
# Filtration: 145
# filtration size 40934
# Filtration: 146
# filtration size 30492
# Filtration: 147
# filtration size 137866
# Filtration: 148
# filtration size 110933
# Filtration: 149
# filtration size 94019
# Filtration: 150
# filtration size 64022
# Filtration: 151
# filtration size 118534
# Filtration: 152
# filtration size 5260
# Filtration: 153
# filtration size 52195
# Filtration: 154
# filtration size 49115
# Filtration: 155
# filtration size 23422
# Filtration: 156
# filtration size 143129
# Filtration: 157
# filtration size 33889
# Filtration: 158
# filtration size 118709
# Filtration: 159
# filtration size 13992
# Filtration: 160
# filtration size 36666
# Filtration: 161
# filtration size 119546
# Filtration: 162
# filtration size 109041
# Filtration: 163
# filtration size 125943
# Filtration: 164
# filtration size 96923
# Filtration: 165
# filtration size 110357
# Filtration: 166
# filtration size 8786
# Filtration: 167
# filtration size 34241
# Filtration: 168
# filtration size 77101
# Filtration: 169
# filtration size 70385
# Filtration: 170
# filtration size 27434
# Filtration: 171
# filtration size 83488
# Filtration: 172
# filtration size 145693
# Filtration: 173
# filtration size 76198
# Filtration: 174
# filtration size 53904
# Filtration: 175
# filtration size 68258
# Filtration: 176
# filtration size 31608
# Filtration: 177
# filtration size 40938
# Filtration: 178
# filtration size 56148
# Filtration: 179
# filtration size 72668
# Filtration: 180
# filtration size 38473
# Filtration: 181
# filtration size 107518
# Filtration: 182
# filtration size 14128
# Filtration: 183
# filtration size 133676
# Filtration: 184
# filtration size 67386
# Filtration: 185
# filtration size 28439
# Filtration: 186
# filtration size 131721
# Filtration: 187
# filtration size 63069
# Filtration: 188
# filtration size 135962
# Filtration: 189
# filtration size 38342
# Filtration: 190
# filtration size 15496
# Filtration: 191
# filtration size 68416
# Filtration: 192
# filtration size 129142
# Filtration: 193
# filtration size 123032
# Filtration: 194
# filtration size 125918
# Filtration: 195
# filtration size 91440
# Filtration: 196
# filtration size 110615
# Filtration: 197
# filtration size 104421
# Filtration: 198
# filtration size 23988
# Filtration: 199
# filtration size 72736
# Filtration: 200
# filtration size 130331
# Filtration: 201
# filtration size 138206
# Filtration: 202
# filtration size 9301
# Filtration: 203
# filtration size 31001
# Filtration: 204
# filtration size 11424
# Filtration: 205
# filtration size 50096
# Filtration: 206
# filtration size 77346
# Filtration: 207
# filtration size 20821
# Filtration: 208
# filtration size 82195
# Filtration: 209
# filtration size 103639
# Filtration: 210
# filtration size 77569
# Filtration: 211
# filtration size 14984
# Filtration: 212
# filtration size 103023
# Filtration: 213
# filtration size 46072
# Filtration: 214
# filtration size 45158
# Filtration: 215
# filtration size 40750
# Filtration: 216
# filtration size 51278
# Filtration: 217
# filtration size 69984
# Filtration: 218
# filtration size 13916
# Filtration: 219
# filtration size 124514
# Filtration: 220
# filtration size 112630
# Filtration: 221
# filtration size 136336
# Filtration: 222
# filtration size 113955
# Filtration: 223
# filtration size 60916
# Filtration: 224
# filtration size 4200
# Filtration: 225
# filtration size 92600
# Filtration: 226
# filtration size 18424
# Filtration: 227
# filtration size 5927
# Filtration: 228
# filtration size 44342
# Filtration: 229
# filtration size 94840
# Filtration: 230
# filtration size 35836
# Filtration: 231
# filtration size 37904
# Filtration: 232
# filtration size 128657
# Filtration: 233
# filtration size 58008
# Filtration: 234
# filtration size 88358
# Filtration: 235
# filtration size 15704
# Filtration: 236
# filtration size 125532
# Filtration: 237
# filtration size 91150
# Filtration: 238
# filtration size 22263
# Filtration: 239
# filtration size 42956
# Filtration: 240
# filtration size 76464
# Filtration: 241
# filtration size 46940
# Filtration: 242
# filtration size 25678
# Filtration: 243
# filtration size 51469
# Filtration: 244
# filtration size 62475
# Filtration: 245
# filtration size 63834
# Filtration: 246
# filtration size 135108
# Filtration: 247
# filtration size 114162
# Filtration: 248
# filtration size 58681
# Filtration: 249
# filtration size 83152
# Filtration: 250
# filtration size 50164
# Filtration: 251
# filtration size 42758
# Filtration: 252
# filtration size 32771
# Filtration: 253
# filtration size 36933
# Filtration: 254
# filtration size 107150
# Filtration: 255
# filtration size 118833
# Filtration: 256
# filtration size 98174
# Filtration: 257
# filtration size 116550
# Filtration: 258
# filtration size 140566
# Filtration: 259
# filtration size 81269
# Filtration: 260
# filtration size 26766
# Filtration: 261
# filtration size 20580
# Filtration: 262
# filtration size 119767
# Filtration: 263
# filtration size 116107
# Filtration: 264
# filtration size 105517
# Filtration: 265
# filtration size 108708
# Filtration: 266
# filtration size 106132
# Filtration: 267
# filtration size 91747
# Filtration: 268
# filtration size 117338
# Filtration: 269
# filtration size 118120
# Filtration: 270
# filtration size 55354
# Filtration: 271
# filtration size 93697
# Filtration: 272
# filtration size 45507
# Filtration: 273
# filtration size 110382
# Filtration: 274
# filtration size 107176
# Filtration: 275
# filtration size 14425
# Filtration: 276
# filtration size 80356
# Filtration: 277
# filtration size 34939
# Filtration: 278
# filtration size 124703
# Filtration: 279
# filtration size 32962
# Filtration: 280
# filtration size 114505
# Filtration: 281
# filtration size 43973
# Filtration: 282
# filtration size 18855
# Filtration: 283
# filtration size 6867
# Filtration: 284
# filtration size 15152
# Filtration: 285
# filtration size 127211
# Filtration: 286
# filtration size 127006
# Filtration: 287
# filtration size 124833
# Filtration: 288
# filtration size 49341
# Filtration: 289
# filtration size 72129
# Filtration: 290
# filtration size 82940
# Filtration: 291
# filtration size 145281
# Filtration: 292
# filtration size 13864
# Filtration: 293
# filtration size 127107
# Filtration: 294
# filtration size 109902
# Filtration: 295
# filtration size 97228
# Filtration: 296
# filtration size 119585
# Filtration: 297
# filtration size 123497
# Filtration: 298
# filtration size 131155
# Filtration: 299
# filtration size 32955
# Filtration: 300
# filtration size 26319
# Filtration: 301
# filtration size 58111
# Filtration: 302
# filtration size 94941
# Filtration: 303
# filtration size 108977
# Filtration: 304
# filtration size 65871
# Filtration: 305
# filtration size 117806
# Filtration: 306
# filtration size 123940
# Filtration: 307
# filtration size 66713
# Filtration: 308
# filtration size 30518
# Filtration: 309
# filtration size 65506
# Filtration: 310
# filtration size 85433
# Filtration: 311
# filtration size 133001
# Filtration: 312
# filtration size 92822
# Filtration: 313
# filtration size 69337
# Filtration: 314
# filtration size 89472
# Filtration: 315
# filtration size 78550
# Filtration: 316
# filtration size 68663
# Filtration: 317
# filtration size 25431
# Filtration: 318
# filtration size 138588
# Filtration: 319
# filtration size 122266
# Filtration: 320
# filtration size 87319
# Filtration: 321
# filtration size 34608
# Filtration: 322
# filtration size 77821
# Filtration: 323
# filtration size 26422
# Filtration: 324
# filtration size 4975
# Filtration: 325
# filtration size 16910
# Filtration: 326
# filtration size 132718
# Filtration: 327
# filtration size 113100
# Filtration: 328
# filtration size 18804
# Filtration: 329
# filtration size 90071
# Filtration: 330
# filtration size 58560
# Filtration: 331
# filtration size 101805
# Filtration: 332
# filtration size 52973
# Filtration: 333
# filtration size 112371
# Filtration: 334
# filtration size 99312
# Filtration: 335
# filtration size 35405
# Filtration: 336
# filtration size 62233
# Filtration: 337
# filtration size 110480
# Filtration: 338
# filtration size 84819
# Filtration: 339
# filtration size 130659
# Filtration: 340
# filtration size 31356
# Filtration: 341
# filtration size 82117
# Filtration: 342
# filtration size 66568
# Filtration: 343
# filtration size 123702
# Filtration: 344
# filtration size 95445
# Filtration: 345
# filtration size 86651
# Filtration: 346
# filtration size 43083
# Filtration: 347
# filtration size 28095
# Filtration: 348
# filtration size 63494
# Filtration: 349
# filtration size 117399
# Filtration: 350
# filtration size 72654
# Filtration: 351
# filtration size 88669
# Filtration: 352
# filtration size 126736
# Filtration: 353
# filtration size 56490
# Filtration: 354
# filtration size 29547
# Filtration: 355
# filtration size 43775
# Filtration: 356
# filtration size 120575
# Filtration: 357
# filtration size 24306
# Filtration: 358
# filtration size 118034
# Filtration: 359
# filtration size 35177
# Filtration: 360
# filtration size 114375
# Filtration: 361
# filtration size 100890
# Filtration: 362
# filtration size 124171
# Filtration: 363
# filtration size 137111
# Filtration: 364
# filtration size 9460
# Filtration: 365
# filtration size 58511
# Filtration: 366
# filtration size 13986
# Filtration: 367
# filtration size 74873
# Filtration: 368
# filtration size 126708
# Filtration: 369
# filtration size 111749
# Filtration: 370
# filtration size 127253
# Filtration: 371
# filtration size 129388
# Filtration: 372
# filtration size 134541
# Filtration: 373
# filtration size 82152
# Filtration: 374
# filtration size 66968
# Filtration: 375
# filtration size 33925
# Filtration: 376
# filtration size 33997
# Filtration: 377
# filtration size 31276
# Filtration: 378
# filtration size 83119
# Filtration: 379
# filtration size 71903
# Filtration: 380
# filtration size 87616
# Filtration: 381
# filtration size 115197
# Filtration: 382
# filtration size 70088
# Filtration: 383
# filtration size 94074
# Filtration: 384
# filtration size 111978
# Filtration: 385
# filtration size 48570
# Filtration: 386
# filtration size 42962
# Filtration: 387
# filtration size 105782
# Filtration: 388
# filtration size 13236
# Filtration: 389
# filtration size 113326
# Filtration: 390
# filtration size 134705
# Filtration: 391
# filtration size 22253
# Filtration: 392
# filtration size 95058
# Filtration: 393
# filtration size 28307
# Filtration: 394
# filtration size 11362
# Filtration: 395
# filtration size 89338
# Filtration: 396
# filtration size 76407
# Filtration: 397
# filtration size 49458
# Filtration: 398
# filtration size 51634
# Filtration: 399
# filtration size 63852
# Filtration: 400
# filtration size 73058
# Filtration: 401
# filtration size 60458
# Filtration: 402
# filtration size 101353
# Filtration: 403
# filtration size 4971
# Filtration: 404
# filtration size 8301
# Filtration: 405
# filtration size 130992
# Filtration: 406
# filtration size 118953
# Filtration: 407
# filtration size 126393
# Filtration: 408
# filtration size 138980
# Filtration: 409
# filtration size 95346
# Filtration: 410
# filtration size 117360
# Filtration: 411
# filtration size 53850
# Filtration: 412
# filtration size 118271
# Filtration: 413
# filtration size 122965
# Filtration: 414
# filtration size 79946
# Filtration: 415
# filtration size 101502
# Filtration: 416
# filtration size 89989
# Filtration: 417
# filtration size 48247
# Filtration: 418
# filtration size 115631
# Filtration: 419
# filtration size 42089
# Filtration: 420
# filtration size 55545
# Filtration: 421
# filtration size 103213
# Filtration: 422
# filtration size 83666
# Filtration: 423
# filtration size 122698
# Filtration: 424
# filtration size 116653
# Filtration: 425
# filtration size 96866
# Filtration: 426
# filtration size 56841
# Filtration: 427
# filtration size 51984
# Filtration: 428
# filtration size 5414
# Filtration: 429
# filtration size 67592
# Filtration: 430
# filtration size 68682
# Filtration: 431
# filtration size 102681
# Filtration: 432
# filtration size 67537
# Filtration: 433
# filtration size 31754
# Filtration: 434
# filtration size 24761
# Filtration: 435
# filtration size 31279
# Filtration: 436
# filtration size 5343
# Filtration: 437
# filtration size 116014
# Filtration: 438
# filtration size 89937
# Filtration: 439
# filtration size 59499
# Filtration: 440
# filtration size 137012
# Filtration: 441
# filtration size 87727
# Filtration: 442
# filtration size 77847
# Filtration: 443
# filtration size 5576
# Filtration: 444
# filtration size 62343
# Filtration: 445
# filtration size 118393
# Filtration: 446
# filtration size 119531
# Filtration: 447
# filtration size 31401
# Filtration: 448
# filtration size 9719
# Filtration: 449
# filtration size 113470
# Filtration: 450
# filtration size 54631
# Filtration: 451
# filtration size 83074
# Filtration: 452
# filtration size 122041
# Filtration: 453
# filtration size 124544
# Filtration: 454
# filtration size 12135
# Filtration: 455
# filtration size 38836
# Filtration: 456
# filtration size 11057
# Filtration: 457
# filtration size 63250
# Filtration: 458
# filtration size 32117
# Filtration: 459
# filtration size 78570
# Filtration: 460
# filtration size 28379
# Filtration: 461
# filtration size 134330
# Filtration: 462
# filtration size 135568
# Filtration: 463
# filtration size 127629
# Filtration: 464
# filtration size 49420
# Filtration: 465
# filtration size 91586
# Filtration: 466
# filtration size 45178
# Filtration: 467
# filtration size 49235
# Filtration: 468
# filtration size 53883
# Filtration: 469
# filtration size 46877
# Filtration: 470
# filtration size 64975
# Filtration: 471
# filtration size 42745
# Filtration: 472
# filtration size 138020
# Filtration: 473
# filtration size 22406
# Filtration: 474
# filtration size 11291
# Filtration: 475
# filtration size 137355
# Filtration: 476
# filtration size 84729
# Filtration: 477
# filtration size 106234
# Filtration: 478
# filtration size 82610
# Filtration: 479
# filtration size 40922
# Filtration: 480
# filtration size 11019
# Filtration: 481
# filtration size 78349
# Filtration: 482
# filtration size 98224
# Filtration: 483
# filtration size 4725
# Filtration: 484
# filtration size 46866
# Filtration: 485
# filtration size 65770
# Filtration: 486
# filtration size 56293
# Filtration: 487
# filtration size 82646
# Filtration: 488
# filtration size 80796
# Filtration: 489
# filtration size 24149
# Filtration: 490
# filtration size 140097
# Filtration: 491
# filtration size 68100
# Filtration: 492
# filtration size 97102
# Filtration: 493
# filtration size 140221
# Filtration: 494
# filtration size 101136
# Filtration: 495
# filtration size 97789
# Filtration: 496
# filtration size 53947
# Filtration: 497
# filtration size 73512
# Filtration: 498
# filtration size 17585
# Filtration: 499
# filtration size 82058
# Filtration: 500
# filtration size 76670
# Filtration: 501
# filtration size 94394
# Filtration: 502
# filtration size 7266
# Filtration: 503
# filtration size 141781
# Filtration: 504
# filtration size 35475
# Filtration: 505
# filtration size 98425
# Filtration: 506
# filtration size 17254
# Filtration: 507
# filtration size 59226
# Filtration: 508
# filtration size 47822
# Filtration: 509
# filtration size 18573
# Filtration: 510
# filtration size 42054
# Filtration: 511
# filtration size 15005
# Filtration: 512
# filtration size 113341
# Filtration: 513
# filtration size 132065
# Filtration: 514
# filtration size 137628
# Filtration: 515
# filtration size 60998
# Filtration: 516
# filtration size 115725
# Filtration: 517
# filtration size 88008
# Filtration: 518
# filtration size 51839
# Filtration: 519
# filtration size 34242
# Filtration: 520
# filtration size 57092
# Filtration: 521
# filtration size 52382
# Filtration: 522
# filtration size 74511
# Filtration: 523
# filtration size 71060
# Filtration: 524
# filtration size 54228
# Filtration: 525
# filtration size 130315
# Filtration: 526
# filtration size 128505
# Filtration: 527
# filtration size 132256
# Filtration: 528
# filtration size 27916
# Filtration: 529
# filtration size 88959
# Filtration: 530
# filtration size 64738
# Filtration: 531
# filtration size 108353
# Filtration: 532
# filtration size 18238
# Filtration: 533
# filtration size 108717
# Filtration: 534
# filtration size 126144
# Filtration: 535
# filtration size 17561
# Filtration: 536
# filtration size 96997
# Filtration: 537
# filtration size 94737
# Filtration: 538
# filtration size 20495
# Filtration: 539
# filtration size 127234
# Filtration: 540
# filtration size 88067
# Filtration: 541
# filtration size 55990
# Filtration: 542
# filtration size 90771
# Filtration: 543
# filtration size 73569
# Filtration: 544
# filtration size 103579
# Filtration: 545
# filtration size 71508
# Filtration: 546
# filtration size 72958
# Filtration: 547
# filtration size 110469
# Filtration: 548
# filtration size 65374
# Filtration: 549
# filtration size 144683
# Filtration: 550
# filtration size 38266
# Filtration: 551
# filtration size 67021
# Filtration: 552
# filtration size 8782
# Filtration: 553
# filtration size 114978
# Filtration: 554
# filtration size 103034
# Filtration: 555
# filtration size 5727
# Filtration: 556
# filtration size 127273
# Filtration: 557
# filtration size 125958
# Filtration: 558
# filtration size 33418
# Filtration: 559
# filtration size 143198
# Filtration: 560
# filtration size 28397
# Filtration: 561
# filtration size 137062
# Filtration: 562
# filtration size 43658
# Filtration: 563
# filtration size 13516
# Filtration: 564
# filtration size 21507
# Filtration: 565
# filtration size 95979
# Filtration: 566
# filtration size 66063
# Filtration: 567
# filtration size 39842
# Filtration: 568
# filtration size 126132
# Filtration: 569
# filtration size 105971
# Filtration: 570
# filtration size 112265
# Filtration: 571
# filtration size 15982
# Filtration: 572
# filtration size 12964
# Filtration: 573
# filtration size 131715
# Filtration: 574
# filtration size 95502
# Filtration: 575
# filtration size 48990
# Filtration: 576
# filtration size 86715
# Filtration: 577
# filtration size 25235
# Filtration: 578
# filtration size 47079
# Filtration: 579
# filtration size 35307
# Filtration: 580
# filtration size 40673
# Filtration: 581
# filtration size 122933
# Filtration: 582
# filtration size 114009
# Filtration: 583
# filtration size 83605
# Filtration: 584
# filtration size 56279
# Filtration: 585
# filtration size 118851
# Filtration: 586
# filtration size 65451
# Filtration: 587
# filtration size 63820
# Filtration: 588
# filtration size 96235
# Filtration: 589
# filtration size 81966
# Filtration: 590
# filtration size 138426
# Filtration: 591
# filtration size 122680
# Filtration: 592
# filtration size 102029
# Filtration: 593
# filtration size 87969
# Filtration: 594
# filtration size 131597
# Filtration: 595
# filtration size 68664
# Filtration: 596
# filtration size 39842
# Filtration: 597
# filtration size 121031
# Filtration: 598
# filtration size 99612
# Filtration: 599
# filtration size 42420
# Filtration: 600
# filtration size 74965
# Filtration: 601
# filtration size 25386
# Filtration: 602
# filtration size 140139
# Filtration: 603
# filtration size 41418
# Filtration: 604
# filtration size 7952
# Filtration: 605
# filtration size 19758
# Filtration: 606
# filtration size 114301
# Filtration: 607
# filtration size 55869
# Filtration: 608
# filtration size 124277
# Filtration: 609
# filtration size 76913
# Filtration: 610
# filtration size 89487
# Filtration: 611
# filtration size 126432
# Filtration: 612
# filtration size 130466
# Filtration: 613
# filtration size 10859
# Filtration: 614
# filtration size 34911
# Filtration: 615
# filtration size 39850
# Filtration: 616
# filtration size 104904
# Filtration: 617
# filtration size 113691
# Filtration: 618
# filtration size 35797
# Filtration: 619
# filtration size 111626
# Filtration: 620
# filtration size 133006
# Filtration: 621
# filtration size 59127
# Filtration: 622
# filtration size 36076
# Filtration: 623
# filtration size 97350
# Filtration: 624
# filtration size 78470
# Filtration: 625
# filtration size 123403
# Filtration: 626
# filtration size 92674
# Filtration: 627
# filtration size 40522
# Filtration: 628
# filtration size 82749
# Filtration: 629
# filtration size 119195
# Filtration: 630
# filtration size 29065
# Filtration: 631
# filtration size 24556
# Filtration: 632
# filtration size 120704
# Filtration: 633
# filtration size 116651
# Filtration: 634
# filtration size 51413
# Filtration: 635
# filtration size 110089
# Filtration: 636
# filtration size 68838
# Filtration: 637
# filtration size 44582
# Filtration: 638
# filtration size 32335
# Filtration: 639
# filtration size 30073
# Filtration: 640
# filtration size 107204
# Filtration: 641
# filtration size 96607
# Filtration: 642
# filtration size 142260
# Filtration: 643
# filtration size 126235
# Filtration: 644
# filtration size 93613
# Filtration: 645
# filtration size 68451
# Filtration: 646
# filtration size 59102
# Filtration: 647
# filtration size 59628
# Filtration: 648
# filtration size 109424
# Filtration: 649
# filtration size 113366
# Filtration: 650
# filtration size 35433
# Filtration: 651
# filtration size 128136
# Filtration: 652
# filtration size 60290
# Filtration: 653
# filtration size 78638
# Filtration: 654
# filtration size 105059
# Filtration: 655
# filtration size 125378
# Filtration: 656
# filtration size 136753
# Filtration: 657
# filtration size 104898
# Filtration: 658
# filtration size 144947
# Filtration: 659
# filtration size 75796
# Filtration: 660
# filtration size 11923
# Filtration: 661
# filtration size 16101
# Filtration: 662
# filtration size 42018
# Filtration: 663
# filtration size 73495
# Filtration: 664
# filtration size 74321
# Filtration: 665
# filtration size 138970
# Filtration: 666
# filtration size 78608
# Filtration: 667
# filtration size 58771
# Filtration: 668
# filtration size 37385
# Filtration: 669
# filtration size 92558
# Filtration: 670
# filtration size 15708
# Filtration: 671
# filtration size 107860
# Filtration: 672
# filtration size 50281
# Filtration: 673
# filtration size 22119
# Filtration: 674
# filtration size 74879
# Filtration: 675
# filtration size 59381
# Filtration: 676
# filtration size 126247
# Filtration: 677
# filtration size 125383
# Filtration: 678
# filtration size 18308
# Filtration: 679
# filtration size 120163
# Filtration: 680
# filtration size 120149
# Filtration: 681
# filtration size 30336
# Filtration: 682
# filtration size 46301
# Filtration: 683
# filtration size 33103
# Filtration: 684
# filtration size 108597
# Filtration: 685
# filtration size 17783
# Filtration: 686
# filtration size 95165
# Filtration: 687
# filtration size 48188
# Filtration: 688
# filtration size 74269
# Filtration: 689
# filtration size 41931
# Filtration: 690
# filtration size 122665
# Filtration: 691
# filtration size 109997
# Filtration: 692
# filtration size 23186
# Filtration: 693
# filtration size 28331
# Filtration: 694
# filtration size 69577
# Filtration: 695
# filtration size 18416
# Filtration: 696
# filtration size 72240
# Filtration: 697
# filtration size 24123
# Filtration: 698
# filtration size 50001
# Filtration: 699
# filtration size 29412
# Filtration: 700
# filtration size 84530
# Filtration: 701
# filtration size 117817
# Filtration: 702
# filtration size 83706
# Filtration: 703
# filtration size 106968
# Filtration: 704
# filtration size 120766
# Filtration: 705
# filtration size 107648
# Filtration: 706
# filtration size 115115
# Filtration: 707
# filtration size 47884
# Filtration: 708
# filtration size 86946
# Filtration: 709
# filtration size 51704
# Filtration: 710
# filtration size 113445
# Filtration: 711
# filtration size 98958
# Filtration: 712
# filtration size 27139
# Filtration: 713
# filtration size 112859
# Filtration: 714
# filtration size 53801
# Filtration: 715
# filtration size 120975
# Filtration: 716
# filtration size 37478
# Filtration: 717
# filtration size 94959
# Filtration: 718
# filtration size 62432
# Filtration: 719
# filtration size 113243
# Filtration: 720
# filtration size 118165
# Filtration: 721
# filtration size 85653
# Filtration: 722
# filtration size 111793
# Filtration: 723
# filtration size 95094
# Filtration: 724
# filtration size 117056
# Filtration: 725
# filtration size 34292
# Filtration: 726
# filtration size 113455
# Filtration: 727
# filtration size 62559
# Filtration: 728
# filtration size 90468
# Filtration: 729
# filtration size 120343
# Filtration: 730
# filtration size 100769
# Filtration: 731
# filtration size 143686
# Filtration: 732
# filtration size 145281
# Filtration: 733
# filtration size 93937
# Filtration: 734
# filtration size 33154
# Filtration: 735
# filtration size 73440
# Filtration: 736
# filtration size 121261
# Filtration: 737
# filtration size 143334
# Filtration: 738
# filtration size 130873
# Filtration: 739
# filtration size 63792
# Filtration: 740
# filtration size 113679
# Filtration: 741
# filtration size 45751
# Filtration: 742
# filtration size 124773
# Filtration: 743
# filtration size 118744
# Filtration: 744
# filtration size 118918
# Filtration: 745
# filtration size 8757
# Filtration: 746
# filtration size 121504
# Filtration: 747
# filtration size 92153
# Filtration: 748
# filtration size 20125
# Filtration: 749
# filtration size 48270
# Filtration: 750
# filtration size 88356
# Filtration: 751
# filtration size 83667
# Filtration: 752
# filtration size 21705
# Filtration: 753
# filtration size 91123
# Filtration: 754
# filtration size 32882
# Filtration: 755
# filtration size 39964
# Filtration: 756
# filtration size 106940
# Filtration: 757
# filtration size 21418
# Filtration: 758
# filtration size 56189
# Filtration: 759
# filtration size 63861
# Filtration: 760
# filtration size 20480
# Filtration: 761
# filtration size 11601
# Filtration: 762
# filtration size 140311
# Filtration: 763
# filtration size 134377
# Filtration: 764
# filtration size 134986
# Filtration: 765
# filtration size 14484
# Filtration: 766
# filtration size 110171
# Filtration: 767
# filtration size 20389
# Filtration: 768
# filtration size 96592
# Filtration: 769
# filtration size 106051
# Filtration: 770
# filtration size 25123
# Filtration: 771
# filtration size 120833
# Filtration: 772
# filtration size 51537
# Filtration: 773
# filtration size 49154
# Filtration: 774
# filtration size 37369
# Filtration: 775
# filtration size 115941
# Filtration: 776
# filtration size 117066
# Filtration: 777
# filtration size 95228
# Filtration: 778
# filtration size 108161
# Filtration: 779
# filtration size 5082
# Filtration: 780
# filtration size 93134
# Filtration: 781
# filtration size 45640
# Filtration: 782
# filtration size 92605
# Filtration: 783
# filtration size 47092
# Filtration: 784
# filtration size 95350
# Filtration: 785
# filtration size 54050
# Filtration: 786
# filtration size 30390
# Filtration: 787
# filtration size 101319
# Filtration: 788
# filtration size 16290
# Filtration: 789
# filtration size 9521
# Filtration: 790
# filtration size 72092
# Filtration: 791
# filtration size 9340
# Filtration: 792
# filtration size 141085
# Filtration: 793
# filtration size 72741
# Filtration: 794
# filtration size 118628
# Filtration: 795
# filtration size 35540
# Filtration: 796
# filtration size 143439
# Filtration: 797
# filtration size 8392
# Filtration: 798
# filtration size 98102
# Filtration: 799
# filtration size 130201
# Filtration: 800
# filtration size 63017
# Filtration: 801
# filtration size 109503
# Filtration: 802
# filtration size 133614
# Filtration: 803
# filtration size 70459
# Filtration: 804
# filtration size 140374
# Filtration: 805
# filtration size 30016
# Filtration: 806
# filtration size 81586
# Filtration: 807
# filtration size 125118
# Filtration: 808
# filtration size 128817
# Filtration: 809
# filtration size 31405
# Filtration: 810
# filtration size 121496
# Filtration: 811
# filtration size 48410
# Filtration: 812
# filtration size 111053
# Filtration: 813
# filtration size 66244
# Filtration: 814
# filtration size 129213
# Filtration: 815
# filtration size 66039
# Filtration: 816
# filtration size 132403
# Filtration: 817
# filtration size 144561
# Filtration: 818
# filtration size 120951
# Filtration: 819
# filtration size 133841
# Filtration: 820
# filtration size 120522
# Filtration: 821
# filtration size 69682
# Filtration: 822
# filtration size 112199
# Filtration: 823
# filtration size 37409
# Filtration: 824
# filtration size 79164
# Filtration: 825
# filtration size 125078
# Filtration: 826
# filtration size 90582
# Filtration: 827
# filtration size 15564
# Filtration: 828
# filtration size 118091
# Filtration: 829
# filtration size 8898
# Filtration: 830
# filtration size 77223
# Filtration: 831
# filtration size 25640
# Filtration: 832
# filtration size 67567
# Filtration: 833
# filtration size 85125
# Filtration: 834
# filtration size 130200
# Filtration: 835
# filtration size 15752
# Filtration: 836
# filtration size 68235
# Filtration: 837
# filtration size 84065
# Filtration: 838
# filtration size 45913
# Filtration: 839
# filtration size 113821
# Filtration: 840
# filtration size 50655
# Filtration: 841
# filtration size 129898
# Filtration: 842
# filtration size 72932
# Filtration: 843
# filtration size 118699
# Filtration: 844
# filtration size 79944
# Filtration: 845
# filtration size 116181
# Filtration: 846
# filtration size 33769
# Filtration: 847
# filtration size 92194
# Filtration: 848
# filtration size 16644
# Filtration: 849
# filtration size 114748
# Filtration: 850
# filtration size 69253
# Filtration: 851
# filtration size 130554
# Filtration: 852
# filtration size 53771
# Filtration: 853
# filtration size 45922
# Filtration: 854
# filtration size 34130
# Filtration: 855
# filtration size 62133
# Filtration: 856
# filtration size 56840
# Filtration: 857
# filtration size 15175
# Filtration: 858
# filtration size 22853
# Filtration: 859
# filtration size 108650
# Filtration: 860
# filtration size 131623
# Filtration: 861
# filtration size 119334
# Filtration: 862
# filtration size 40697
# Filtration: 863
# filtration size 106291
# Filtration: 864
# filtration size 94554
# Filtration: 865
# filtration size 95963
# Filtration: 866
# filtration size 103507
# Filtration: 867
# filtration size 95581
# Filtration: 868
# filtration size 62888
# Filtration: 869
# filtration size 91703
# Filtration: 870
# filtration size 35621
# Filtration: 871
# filtration size 126785
# Filtration: 872
# filtration size 33225
# Filtration: 873
# filtration size 125379
# Filtration: 874
# filtration size 20815
# Filtration: 875
# filtration size 110710
# Filtration: 876
# filtration size 135553
# Filtration: 877
# filtration size 107844
# Filtration: 878
# filtration size 77993
# Filtration: 879
# filtration size 25309
# Filtration: 880
# filtration size 34912
# Filtration: 881
# filtration size 101077
# Filtration: 882
# filtration size 30150
# Filtration: 883
# filtration size 27626
# Filtration: 884
# filtration size 83708
# Filtration: 885
# filtration size 72191
# Filtration: 886
# filtration size 118037
# Filtration: 887
# filtration size 103198
# Filtration: 888
# filtration size 137756
# Filtration: 889
# filtration size 58630
# Filtration: 890
# filtration size 104191
# Filtration: 891
# filtration size 121987
# Filtration: 892
# filtration size 137958
# Filtration: 893
# filtration size 52699
# Filtration: 894
# filtration size 129241
# Filtration: 895
# filtration size 78127
# Filtration: 896
# filtration size 137573
# Filtration: 897
# filtration size 79772
# Filtration: 898
# filtration size 39019
# Filtration: 899
# filtration size 71130
# Filtration: 900
# filtration size 62290
# Filtration: 901
# filtration size 117439
# Filtration: 902
# filtration size 122155
# Filtration: 903
# filtration size 127962
# Filtration: 904
# filtration size 100835
# Filtration: 905
# filtration size 141415
# Filtration: 906
# filtration size 38221
# Filtration: 907
# filtration size 7960
# Filtration: 908
# filtration size 39626
# Filtration: 909
# filtration size 110641
# Filtration: 910
# filtration size 68174
# Filtration: 911
# filtration size 119391
# Filtration: 912
# filtration size 124535
# Filtration: 913
# filtration size 47401
# Filtration: 914
# filtration size 65179
# Filtration: 915
# filtration size 108688
# Filtration: 916
# filtration size 129902
# Filtration: 917
# filtration size 106108
# Filtration: 918
# filtration size 39973
# Filtration: 919
# filtration size 87189
# Filtration: 920
# filtration size 31334
# Filtration: 921
# filtration size 134513
# Filtration: 922
# filtration size 32705
# Filtration: 923
# filtration size 132568
# Filtration: 924
# filtration size 80563
# Filtration: 925
# filtration size 123525
# Filtration: 926
# filtration size 67135
# Filtration: 927
# filtration size 129795
# Filtration: 928
# filtration size 7321
# Filtration: 929
# filtration size 23021
# Filtration: 930
# filtration size 31618
# Filtration: 931
# filtration size 88359
# Filtration: 932
# filtration size 130479
# Filtration: 933
# filtration size 131100
# Filtration: 934
# filtration size 72415
# Filtration: 935
# filtration size 48653
# Filtration: 936
# filtration size 73889
# Filtration: 937
# filtration size 144607
# Filtration: 938
# filtration size 114064
# Filtration: 939
# filtration size 91704
# Filtration: 940
# filtration size 104158
# Filtration: 941
# filtration size 107507
# Filtration: 942
# filtration size 112981
# Filtration: 943
# filtration size 58754
# Filtration: 944
# filtration size 78846
# Filtration: 945
# filtration size 136195
# Filtration: 946
# filtration size 101590
# Filtration: 947
# filtration size 41357
# Filtration: 948
# filtration size 38248
# Filtration: 949
# filtration size 92577
# Filtration: 950
# filtration size 97887
# Filtration: 951
# filtration size 109040
# Filtration: 952
# filtration size 141204
# Filtration: 953
# filtration size 10670
# Filtration: 954
# filtration size 85512
# Filtration: 955
# filtration size 78614
# Filtration: 956
# filtration size 120679
# Filtration: 957
# filtration size 36434
# Filtration: 958
# filtration size 76466
# Filtration: 959
# filtration size 78833
# Filtration: 960
# filtration size 20607
# Filtration: 961
# filtration size 28873
# Filtration: 962
# filtration size 76746
# Filtration: 963
# filtration size 19093
# Filtration: 964
# filtration size 6497
# Filtration: 965
# filtration size 120204
# Filtration: 966
# filtration size 57724
# Filtration: 967
# filtration size 81458
# Filtration: 968
# filtration size 41650
# Filtration: 969
# filtration size 91711
# Filtration: 970
# filtration size 39296
# Filtration: 971
# filtration size 80595
# Filtration: 972
# filtration size 121296
# Filtration: 973
# filtration size 108705
# Filtration: 974
# filtration size 95883
# Filtration: 975
# filtration size 123046
# Filtration: 976
# filtration size 65552
# Filtration: 977
# filtration size 94308
# Filtration: 978
# filtration size 100757
# Filtration: 979
# filtration size 95223
# Filtration: 980
# filtration size 63475
# Filtration: 981
# filtration size 122613
# Filtration: 982
# filtration size 89366
# Filtration: 983
# filtration size 56497
# Filtration: 984
# filtration size 57421
# Filtration: 985
# filtration size 132206
# Filtration: 986
# filtration size 117535
# Filtration: 987
# filtration size 106683
# Filtration: 988
# filtration size 37987
# Filtration: 989
# filtration size 100571
# Filtration: 990
# filtration size 88628
# Filtration: 991
# filtration size 95261
# Filtration: 992
# filtration size 67884
# Filtration: 993
# filtration size 86617
# Filtration: 994
# filtration size 85701
# Filtration: 995
# filtration size 138552
# Filtration: 996
# filtration size 125367
# Filtration: 997
# filtration size 119825
# Filtration: 998
# filtration size 53418
# Filtration: 999
# filtration size 59097
# Filtration: 1000
# filtration size 40127
# Filtration: 1001
# filtration size 53744
# Filtration: 1002
# filtration size 105962
# Filtration: 1003
# filtration size 123010
# Filtration: 1004
# filtration size 56915
# Filtration: 1005
# filtration size 25667
# Filtration: 1006
# filtration size 117244
# Filtration: 1007
# filtration size 40938
# Filtration: 1008
# filtration size 103345
# Filtration: 1009
# filtration size 135059
# Filtration: 1010
# filtration size 93189
# Filtration: 1011
# filtration size 107584
# Filtration: 1012
# filtration size 26678
# Filtration: 1013
# filtration size 27614
# Filtration: 1014
# filtration size 62666
# Filtration: 1015
# filtration size 51381
# Filtration: 1016
# filtration size 93645
# Filtration: 1017
# filtration size 145794
# Filtration: 1018
# filtration size 64020
# Filtration: 1019
# filtration size 11675
# Filtration: 1020
# filtration size 93164
# Filtration: 1021
# filtration size 69388
# Filtration: 1022
# filtration size 121435
# Filtration: 1023
# filtration size 127982
# Filtration: 1024
# filtration size 9925
# Filtration: 1025
# filtration size 46838
# Filtration: 1026
# filtration size 78449
# Filtration: 1027
# filtration size 56174
# Filtration: 1028
# filtration size 79766
# Filtration: 1029
# filtration size 15123
# Filtration: 1030
# filtration size 44577
# Filtration: 1031
# filtration size 20633
# Filtration: 1032
# filtration size 109189
# Filtration: 1033
# filtration size 43068
# Filtration: 1034
# filtration size 121582
# Filtration: 1035
# filtration size 138357
# Filtration: 1036
# filtration size 106021
# Filtration: 1037
# filtration size 86246
# Filtration: 1038
# filtration size 38473
# Filtration: 1039
# filtration size 37672
# Filtration: 1040
# filtration size 52098
# Filtration: 1041
# filtration size 16587
# Filtration: 1042
# filtration size 64375
# Filtration: 1043
# filtration size 82931
# Filtration: 1044
# filtration size 58732
# Filtration: 1045
# filtration size 84956
# Filtration: 1046
# filtration size 17467
# Filtration: 1047
# filtration size 127243
# Filtration: 1048
# filtration size 6491
# Filtration: 1049
# filtration size 136663
# Filtration: 1050
# filtration size 120490
# Filtration: 1051
# filtration size 86903
# Filtration: 1052
# filtration size 47905
# Filtration: 1053
# filtration size 137179
# Filtration: 1054
# filtration size 94536
# Filtration: 1055
# filtration size 93993
# Filtration: 1056
# filtration size 105384
# Filtration: 1057
# filtration size 11185
# Filtration: 1058
# filtration size 31376
# Filtration: 1059
# filtration size 25891
# Filtration: 1060
# filtration size 125359
# Filtration: 1061
# filtration size 128336
# Filtration: 1062
# filtration size 29541
# Filtration: 1063
# filtration size 8571
# Filtration: 1064
# filtration size 90135
# Filtration: 1065
# filtration size 127501
# Filtration: 1066
# filtration size 95000
# Filtration: 1067
# filtration size 17642
# Filtration: 1068
# filtration size 8273
# Filtration: 1069
# filtration size 83813
# Filtration: 1070
# filtration size 74017
# Filtration: 1071
# filtration size 89499
# Filtration: 1072
# filtration size 33377
# Filtration: 1073
# filtration size 83191
# Filtration: 1074
# filtration size 69149
# Filtration: 1075
# filtration size 31818
# Filtration: 1076
# filtration size 80153
# Filtration: 1077
# filtration size 106475
# Filtration: 1078
# filtration size 25745
# Filtration: 1079
# filtration size 16508
# Filtration: 1080
# filtration size 12543
# Filtration: 1081
# filtration size 91275
# Filtration: 1082
# filtration size 53268
# Filtration: 1083
# filtration size 52860
# Filtration: 1084
# filtration size 123918
# Filtration: 1085
# filtration size 66657
# Filtration: 1086
# filtration size 36176
# Filtration: 1087
# filtration size 5615
# Filtration: 1088
# filtration size 33682
# Filtration: 1089
# filtration size 49222
# Filtration: 1090
# filtration size 6115
# Filtration: 1091
# filtration size 22392
# Filtration: 1092
# filtration size 68156
# Filtration: 1093
# filtration size 87952
# Filtration: 1094
# filtration size 92479
# Filtration: 1095
# filtration size 41650
# Filtration: 1096
# filtration size 114183
# Filtration: 1097
# filtration size 60190
# Filtration: 1098
# filtration size 40146
# Filtration: 1099
# filtration size 41960
# Filtration: 1100
# filtration size 106847
# Filtration: 1101
# filtration size 117092
# Filtration: 1102
# filtration size 117419
# Filtration: 1103
# filtration size 87263
# Filtration: 1104
# filtration size 78134
# Filtration: 1105
# filtration size 57116
# Filtration: 1106
# filtration size 111872
# Filtration: 1107
# filtration size 48851
# Filtration: 1108
# filtration size 105483
# Filtration: 1109
# filtration size 112819
# Filtration: 1110
# filtration size 81825
# Filtration: 1111
# filtration size 36279
# Filtration: 1112
# filtration size 56841
# Filtration: 1113
# filtration size 98695
# Filtration: 1114
# filtration size 53854
# Filtration: 1115
# filtration size 19172
# Filtration: 1116
# filtration size 12515
# Filtration: 1117
# filtration size 71638
# Filtration: 1118
# filtration size 96029
# Filtration: 1119
# filtration size 52442
# Filtration: 1120
# filtration size 15325
# Filtration: 1121
# filtration size 68673
# Filtration: 1122
# filtration size 110381
# Filtration: 1123
# filtration size 85269
# Filtration: 1124
# filtration size 6375
# Filtration: 1125
# filtration size 99619
# Filtration: 1126
# filtration size 65400
# Filtration: 1127
# filtration size 36645
# Filtration: 1128
# filtration size 109103
# Filtration: 1129
# filtration size 38835
# Filtration: 1130
# filtration size 14396
# Filtration: 1131
# filtration size 75917
# Filtration: 1132
# filtration size 78232
# Filtration: 1133
# filtration size 85969
# Filtration: 1134
# filtration size 118822
# Filtration: 1135
# filtration size 12137
# Filtration: 1136
# filtration size 34779
# Filtration: 1137
# filtration size 37358
# Filtration: 1138
# filtration size 30142
# Filtration: 1139
# filtration size 80370
# Filtration: 1140
# filtration size 22046
# Filtration: 1141
# filtration size 118001
# Filtration: 1142
# filtration size 20335
# Filtration: 1143
# filtration size 60411
# Filtration: 1144
# filtration size 61878
# Filtration: 1145
# filtration size 109140
# Filtration: 1146
# filtration size 39125
# Filtration: 1147
# filtration size 125528
# Filtration: 1148
# filtration size 113592
# Filtration: 1149
# filtration size 48707
# Filtration: 1150
# filtration size 126526
# Filtration: 1151
# filtration size 123770
# Filtration: 1152
# filtration size 121224
# Filtration: 1153
# filtration size 35318
# Filtration: 1154
# filtration size 102217
# Filtration: 1155
# filtration size 91485
# Filtration: 1156
# filtration size 58878
# Filtration: 1157
# filtration size 12716
# Filtration: 1158
# filtration size 134214
# Filtration: 1159
# filtration size 43124
# Filtration: 1160
# filtration size 40711
# Filtration: 1161
# filtration size 86513
# Filtration: 1162
# filtration size 140627
# Filtration: 1163
# filtration size 40521
# Filtration: 1164
# filtration size 99494
# Filtration: 1165
# filtration size 56868
# Filtration: 1166
# filtration size 49100
# Filtration: 1167
# filtration size 44099
# Filtration: 1168
# filtration size 6667
# Filtration: 1169
# filtration size 29261
# Filtration: 1170
# filtration size 37261
# Filtration: 1171
# filtration size 116053
# Filtration: 1172
# filtration size 118770
# Filtration: 1173
# filtration size 14740
# Filtration: 1174
# filtration size 142634
# Filtration: 1175
# filtration size 111229
# Filtration: 1176
# filtration size 131715
# Filtration: 1177
# filtration size 119072
# Filtration: 1178
# filtration size 19083
# Filtration: 1179
# filtration size 54948
# Filtration: 1180
# filtration size 107763
# Filtration: 1181
# filtration size 47683
# Filtration: 1182
# filtration size 138302
# Filtration: 1183
# filtration size 39207
# Filtration: 1184
# filtration size 39306
# Filtration: 1185
# filtration size 21681
# Filtration: 1186
# filtration size 125218
# Filtration: 1187
# filtration size 89763
# Filtration: 1188
# filtration size 79887
# Filtration: 1189
# filtration size 53926
# Filtration: 1190
# filtration size 23897
# Filtration: 1191
# filtration size 122029
# Filtration: 1192
# filtration size 84555
# Filtration: 1193
# filtration size 38468
# Filtration: 1194
# filtration size 68303
# Filtration: 1195
# filtration size 111693
# Filtration: 1196
# filtration size 93856
# Filtration: 1197
# filtration size 31999
# Filtration: 1198
# filtration size 95207
# Filtration: 1199
# filtration size 81116
# Filtration: 1200
# filtration size 39405
# Filtration: 1201
# filtration size 74458
# Filtration: 1202
# filtration size 103636
# Filtration: 1203
# filtration size 129364
# Filtration: 1204
# filtration size 53930
# Filtration: 1205
# filtration size 79361
# Filtration: 1206
# filtration size 117483
# Filtration: 1207
# filtration size 133336
# Filtration: 1208
# filtration size 34500
# Filtration: 1209
# filtration size 37966
# Filtration: 1210
# filtration size 104916
# Filtration: 1211
# filtration size 34864
# Filtration: 1212
# filtration size 30883
# Filtration: 1213
# filtration size 48254
# Filtration: 1214
# filtration size 74639
# Filtration: 1215
# filtration size 71428
# Filtration: 1216
# filtration size 102971
# Filtration: 1217
# filtration size 50251
# Filtration: 1218
# filtration size 115138
# Filtration: 1219
# filtration size 30888
# Filtration: 1220
# filtration size 99451
# Filtration: 1221
# filtration size 44219
# Filtration: 1222
# filtration size 22888
# Filtration: 1223
# filtration size 103802
# Filtration: 1224
# filtration size 121985
# Filtration: 1225
# filtration size 70908
# Filtration: 1226
# filtration size 106134
# Filtration: 1227
# filtration size 99293
# Filtration: 1228
# filtration size 35671
# Filtration: 1229
# filtration size 25094
# Filtration: 1230
# filtration size 20268
# Filtration: 1231
# filtration size 99084
# Filtration: 1232
# filtration size 33468
# Filtration: 1233
# filtration size 124555
# Filtration: 1234
# filtration size 116107
# Filtration: 1235
# filtration size 105583
# Filtration: 1236
# filtration size 31262
# Filtration: 1237
# filtration size 117574
# Filtration: 1238
# filtration size 64704
# Filtration: 1239
# filtration size 20841
# Filtration: 1240
# filtration size 72397
# Filtration: 1241
# filtration size 10160
# Filtration: 1242
# filtration size 13779
# Filtration: 1243
# filtration size 101734
# Filtration: 1244
# filtration size 119223
# Filtration: 1245
# filtration size 129833
# Filtration: 1246
# filtration size 90151
# Filtration: 1247
# filtration size 128977
# Filtration: 1248
# filtration size 97541
# Filtration: 1249
# ...
# filtration size 58438
# Filtration: 1594
# filtration size 79856
# Filtration: 1595
# filtration size 113709
# Filtration: 1596
# filtration size 19216
# Filtration: 1597
# filtration size 55126
# Filtration: 1598
# filtration size 103598
# Filtration: 1599
# filtration size 28526
# Filtration: 1600
# filtration size 36898
# Filtration: 1601
# filtration size 68970
# Filtration: 1602
# filtration size 124915
# Filtration: 1603
# filtration size 108796
# Filtration: 1604
# filtration size 143636
# Filtration: 1605
# filtration size 94278
# Filtration: 1606
# filtration size 113593
# Filtration: 1607
# filtration size 56082
# Filtration: 1608
# filtration size 122222
# Filtration: 1609
# filtration size 99935
# Filtration: 1610
# filtration size 132017
# Filtration: 1611
# filtration size 56269
# Filtration: 1612
# filtration size 99858
# Filtration: 1613
# filtration size 77610
# Filtration: 1614
# filtration size 12026
# Filtration: 1615
# filtration size 58664
# Filtration: 1616
# filtration size 133944
# Filtration: 1617
# filtration size 100018
# Filtration: 1618
# filtration size 119042
# Filtration: 1619
# filtration size 32425
# Filtration: 1620
# filtration size 127060
# Filtration: 1621
# filtration size 127596
# Filtration: 1622
# filtration size 76786
# Filtration: 1623
# filtration size 112148
# Filtration: 1624
# filtration size 125393
# Filtration: 1625
# filtration size 39973
# Filtration: 1626
# filtration size 37762
# Filtration: 1627
# filtration size 40235
# Filtration: 1628
# filtration size 88771
# Filtration: 1629
# filtration size 93190
# Filtration: 1630
# filtration size 85763
# Filtration: 1631
# filtration size 113607
# Filtration: 1632
# filtration size 104201
# Filtration: 1633
# filtration size 79593
# Filtration: 1634
# filtration size 53585
# Filtration: 1635
# filtration size 35539
# Filtration: 1636
# filtration size 88753
# Filtration: 1637
# filtration size 61568
# Filtration: 1638
# filtration size 19985
# Filtration: 1639
# filtration size 51414
# Filtration: 1640
# filtration size 137728
# Filtration: 1641
# filtration size 86649
# Filtration: 1642
# filtration size 115269
# Filtration: 1643
# filtration size 102646
# Filtration: 1644
# filtration size 80852
# Filtration: 1645
# filtration size 26660
# Filtration: 1646
# filtration size 14214
# Filtration: 1647
# filtration size 8399
# Filtration: 1648
# filtration size 110062
# Filtration: 1649
# filtration size 80831
# Filtration: 1650
# filtration size 141422
# Filtration: 1651
# filtration size 25796
# Filtration: 1652
# filtration size 106495
# Filtration: 1653
# filtration size 28105
# Filtration: 1654
# filtration size 90854
# Filtration: 1655
# filtration size 10276
# Filtration: 1656
# filtration size 136031
# Filtration: 1657
# filtration size 57755
# Filtration: 1658
# filtration size 77459
# Filtration: 1659
# filtration size 16671
# Filtration: 1660
# filtration size 31043
# Filtration: 1661
# filtration size 112326
# Filtration: 1662
# filtration size 118003
# Filtration: 1663
# filtration size 72523
# Filtration: 1664
# filtration size 108841
# Filtration: 1665
# filtration size 21174
# Filtration: 1666
# filtration size 56381
# Filtration: 1667
# filtration size 84419
# Filtration: 1668
# filtration size 42159
# Filtration: 1669
# filtration size 21536
# Filtration: 1670
# filtration size 69102
# Filtration: 1671
# filtration size 135126
# Filtration: 1672
# filtration size 70412
# Filtration: 1673
# filtration size 78683
# Filtration: 1674
# filtration size 35514
# Filtration: 1675
# filtration size 67415
# Filtration: 1676
# filtration size 51317
# Filtration: 1677
# filtration size 19185
# Filtration: 1678
# filtration size 48514
# Filtration: 1679
# filtration size 114468
# Filtration: 1680
# filtration size 9936
# Filtration: 1681
# filtration size 110831
# Filtration: 1682
# filtration size 120599
# Filtration: 1683
# filtration size 86746
# Filtration: 1684
# filtration size 25551
# Filtration: 1685
# filtration size 101773
# Filtration: 1686
# filtration size 118637
# Filtration: 1687
# filtration size 27536
# Filtration: 1688
# filtration size 130944
# Filtration: 1689
# filtration size 6606
# Filtration: 1690
# filtration size 52162
# Filtration: 1691
# filtration size 103994
# Filtration: 1692
# filtration size 140231
# Filtration: 1693
# filtration size 12505
# Filtration: 1694
# filtration size 86999
# Filtration: 1695
# filtration size 36532
# Filtration: 1696
# filtration size 51802
# Filtration: 1697
# filtration size 28007
# Filtration: 1698
# filtration size 119444
# Filtration: 1699
# filtration size 110595
# Filtration: 1700
# filtration size 115495
# Filtration: 1701
# filtration size 103568
# Filtration: 1702
# filtration size 77734
# Filtration: 1703
# filtration size 55758
# Filtration: 1704
# filtration size 18766
# Filtration: 1705
# filtration size 100768
# Filtration: 1706
# filtration size 105243
# Filtration: 1707
# filtration size 71692
# Filtration: 1708
# filtration size 101114
# Filtration: 1709
# filtration size 113537
# Filtration: 1710
# filtration size 98263
# Filtration: 1711
# filtration size 106126
# Filtration: 1712
# filtration size 137355
# Filtration: 1713
# filtration size 65713
# Filtration: 1714
# filtration size 90337
# Filtration: 1715
# filtration size 58620
# Filtration: 1716
# filtration size 8938
# Filtration: 1717
# filtration size 119149
# Filtration: 1718
# filtration size 136452
# Filtration: 1719
# filtration size 21913
# Filtration: 1720
# filtration size 87545
# Filtration: 1721
# filtration size 92630
# Filtration: 1722
# filtration size 42503
# Filtration: 1723
# filtration size 114101
# Filtration: 1724
# filtration size 31743
# Filtration: 1725
# filtration size 116949
# Filtration: 1726
# filtration size 105054
# Filtration: 1727
# filtration size 65246
# Filtration: 1728
# filtration size 36200
# Filtration: 1729
# filtration size 65673
# Filtration: 1730
# filtration size 44842
# Filtration: 1731
# filtration size 118729
# Filtration: 1732
# filtration size 100086
# Filtration: 1733
# filtration size 122063
# Filtration: 1734
# filtration size 125185
# Filtration: 1735
# filtration size 7243
# Filtration: 1736
# filtration size 39843
# Filtration: 1737
# filtration size 105737
# Filtration: 1738
# filtration size 106133
# Filtration: 1739
# filtration size 98267
# Filtration: 1740
# filtration size 70628
# Filtration: 1741
# filtration size 39099
# Filtration: 1742
# filtration size 127335
# Filtration: 1743
# filtration size 23437
# Filtration: 1744
# filtration size 54272
# Filtration: 1745
# filtration size 50259
# Filtration: 1746
# filtration size 88295
# Filtration: 1747
# filtration size 80135
# Filtration: 1748
# filtration size 137933
# Filtration: 1749
# filtration size 108803
# Filtration: 1750
# filtration size 79378
# Filtration: 1751
# filtration size 87001
# Filtration: 1752
# filtration size 32160
# Filtration: 1753
# filtration size 68194
# Filtration: 1754
# filtration size 83231
# Filtration: 1755
# filtration size 11499
# Filtration: 1756
# filtration size 37850
# Filtration: 1757
# filtration size 30805
# Filtration: 1758
# filtration size 125943
# Filtration: 1759
# filtration size 4688
# Filtration: 1760
# filtration size 88999
# Filtration: 1761
# filtration size 19221
# Filtration: 1762
# filtration size 49515
# Filtration: 1763
# filtration size 27537
# Filtration: 1764
# filtration size 128275
# Filtration: 1765
# filtration size 30721
# Filtration: 1766
# filtration size 19293
# Filtration: 1767
# filtration size 7690
# Filtration: 1768
# filtration size 104570
# Filtration: 1769
# filtration size 88864
# Filtration: 1770
# filtration size 42681
# Filtration: 1771
# filtration size 58622
# Filtration: 1772
# filtration size 79755
# Filtration: 1773
# filtration size 37322
# Filtration: 1774
# filtration size 73514
# Filtration: 1775
# filtration size 57048
# Filtration: 1776
# filtration size 115796
# Filtration: 1777
# filtration size 106548
# Filtration: 1778
# filtration size 70929
# Filtration: 1779
# filtration size 120310
# Filtration: 1780
# filtration size 65776
# Filtration: 1781
# filtration size 19082
# Filtration: 1782
# filtration size 67491
# Filtration: 1783
# filtration size 104944
# Filtration: 1784
# filtration size 96777
# Filtration: 1785
# filtration size 107029
# Filtration: 1786
# filtration size 26274
# Filtration: 1787
# filtration size 37237
# Filtration: 1788
# filtration size 33196
# Filtration: 1789
# filtration size 23595
# Filtration: 1790
# filtration size 44369
# Filtration: 1791
# filtration size 67700
# Filtration: 1792
# filtration size 65800
# Filtration: 1793
# filtration size 102711
# Filtration: 1794
# filtration size 132905
# Filtration: 1795
# filtration size 124506
# Filtration: 1796
# filtration size 121135
# Filtration: 1797
# filtration size 108185
# Filtration: 1798
# filtration size 51632
# Filtration: 1799
# filtration size 106218
# Filtration: 1800
# filtration size 107622
# Filtration: 1801
# filtration size 66489
# Filtration: 1802
# filtration size 21682
# Filtration: 1803
# filtration size 77516
# Filtration: 1804
# filtration size 107074
# Filtration: 1805
# filtration size 71161
# Filtration: 1806
# filtration size 118163
# Filtration: 1807
# filtration size 112106
# Filtration: 1808
# filtration size 126560
# Filtration: 1809
# filtration size 92540
# Filtration: 1810
# filtration size 78881
# Filtration: 1811
# filtration size 127529
# Filtration: 1812
# filtration size 28758
# Filtration: 1813
# filtration size 78472
# Filtration: 1814
# filtration size 48492
# Filtration: 1815
# filtration size 88922
# Filtration: 1816
# filtration size 10949
# Filtration: 1817
# filtration size 138484
# Filtration: 1818
# filtration size 108876
# Filtration: 1819
# filtration size 45355
# Filtration: 1820
# filtration size 19577
# Filtration: 1821
# filtration size 23833
# Filtration: 1822
# filtration size 115446
# Filtration: 1823
# filtration size 57847
# Filtration: 1824
# filtration size 94369
# Filtration: 1825
# filtration size 40664
# Filtration: 1826
# filtration size 85907
# Filtration: 1827
# filtration size 102190
# Filtration: 1828
# filtration size 106837
# Filtration: 1829
# filtration size 58567
# Filtration: 1830
# filtration size 40632
# Filtration: 1831
# filtration size 108942
# Filtration: 1832
# filtration size 36260
# Filtration: 1833
# filtration size 48585
# Filtration: 1834
# filtration size 64847
# Filtration: 1835
# filtration size 56461
# Filtration: 1836
# filtration size 13816
# Filtration: 1837
# filtration size 20432
# Filtration: 1838
# filtration size 89483
# Filtration: 1839
# filtration size 119325
# Filtration: 1840
# filtration size 110373
# Filtration: 1841
# filtration size 58357
# Filtration: 1842
# filtration size 86755
# Filtration: 1843
# filtration size 114785
# Filtration: 1844
# filtration size 29315
# Filtration: 1845
# filtration size 80404
# Filtration: 1846
# filtration size 31414
# Filtration: 1847
# filtration size 65057
# Filtration: 1848
# filtration size 53804
# Filtration: 1849
# filtration size 13326
# Filtration: 1850
# filtration size 83469
# Filtration: 1851
# filtration size 82140
# Filtration: 1852
# filtration size 111173
# Filtration: 1853
# filtration size 15333
# Filtration: 1854
# filtration size 115268
# Filtration: 1855
# filtration size 37697
# Filtration: 1856
# filtration size 115747
# Filtration: 1857
# filtration size 110202
# Filtration: 1858
# filtration size 110155
# Filtration: 1859
# filtration size 117886
# Filtration: 1860
# filtration size 15500
# Filtration: 1861
# filtration size 63966
# Filtration: 1862
# filtration size 21735
# Filtration: 1863
# filtration size 131309
# Filtration: 1864
# filtration size 28208
# Filtration: 1865
# filtration size 52312
# Filtration: 1866
# filtration size 86656
# Filtration: 1867
# filtration size 50564
# Filtration: 1868
# filtration size 14117
# Filtration: 1869
# filtration size 52102
# Filtration: 1870
# filtration size 120577
# Filtration: 1871
# filtration size 122296
# Filtration: 1872
# filtration size 28391
# Filtration: 1873
# filtration size 45516
# Filtration: 1874
# filtration size 68633
# Filtration: 1875
# filtration size 113024
# Filtration: 1876
# filtration size 40464
# Filtration: 1877
# filtration size 10338
# Filtration: 1878
# filtration size 117965
# Filtration: 1879
# filtration size 40579
# Filtration: 1880
# filtration size 133812
# Filtration: 1881
# filtration size 104178
# Filtration: 1882
# filtration size 38713
# Filtration: 1883
# filtration size 128682
# Filtration: 1884
# filtration size 70823
# Filtration: 1885
# filtration size 47134
# Filtration: 1886
# filtration size 66343
# Filtration: 1887
# filtration size 97349
# Filtration: 1888
# filtration size 118100
# Filtration: 1889
# filtration size 99514
# Filtration: 1890
# filtration size 120645
# Filtration: 1891
# filtration size 142908
# Filtration: 1892
# filtration size 141344
# Filtration: 1893
# filtration size 69196
# Filtration: 1894
# filtration size 47759
# Filtration: 1895
# filtration size 140758
# Filtration: 1896
# filtration size 50662
# Filtration: 1897
# filtration size 37465
# Filtration: 1898
# filtration size 70394
# Filtration: 1899
# filtration size 112974
# Filtration: 1900
# filtration size 58531
# Filtration: 1901
# filtration size 33080
# Filtration: 1902
# filtration size 32414
# Filtration: 1903
# filtration size 76801
# Filtration: 1904
# filtration size 51250
# Filtration: 1905
# filtration size 132433
# Filtration: 1906
# filtration size 15719
# Filtration: 1907
# filtration size 76470
# Filtration: 1908
# filtration size 119773
# Filtration: 1909
# filtration size 58844
# Filtration: 1910
# filtration size 68946
# Filtration: 1911
# filtration size 24599
# Filtration: 1912
# filtration size 23802
# Filtration: 1913
# filtration size 40197
# Filtration: 1914
# filtration size 47054
# Filtration: 1915
# filtration size 97487
# Filtration: 1916
# filtration size 110018
# Filtration: 1917
# filtration size 50024
# Filtration: 1918
# filtration size 46492
# Filtration: 1919
# filtration size 108155
# Filtration: 1920
# filtration size 12175
# Filtration: 1921
# filtration size 103582
# Filtration: 1922
# filtration size 45935
# Filtration: 1923
# filtration size 90225
# Filtration: 1924
# filtration size 115916
# Filtration: 1925
# filtration size 104173
# Filtration: 1926
# filtration size 49756
# Filtration: 1927
# filtration size 93473
# Filtration: 1928
# filtration size 73837
# Filtration: 1929
# filtration size 12168
# Filtration: 1930
# filtration size 98108
# Filtration: 1931
# filtration size 80832
# Filtration: 1932
# filtration size 110720
# Filtration: 1933
# filtration size 84054
# Filtration: 1934
# filtration size 70928
# Filtration: 1935
# filtration size 90885
# Filtration: 1936
# filtration size 135193
# Filtration: 1937
# filtration size 133494
# Filtration: 1938
# filtration size 126280
# Filtration: 1939
# filtration size 84384
# Filtration: 1940
# filtration size 35325
# Filtration: 1941
# filtration size 40934
# Filtration: 1942
# filtration size 10075
# Filtration: 1943
# filtration size 120396
# Filtration: 1944
# filtration size 128812
# Filtration: 1945
# filtration size 58733
# Filtration: 1946
# filtration size 46150
# Filtration: 1947
# filtration size 135296
# Filtration: 1948
# filtration size 26622
# Filtration: 1949
# filtration size 14686
# Filtration: 1950
# filtration size 92237
# Filtration: 1951
# filtration size 95509
# Filtration: 1952
# filtration size 8795
# Filtration: 1953
# filtration size 37080
# Filtration: 1954
# filtration size 79130
# Filtration: 1955
# filtration size 126858
# Filtration: 1956
# filtration size 55990
# Filtration: 1957
# filtration size 82726
# Filtration: 1958
# filtration size 106879
# Filtration: 1959
# filtration size 75210
# Filtration: 1960
# filtration size 73133
# Filtration: 1961
# filtration size 54567
# Filtration: 1962
# filtration size 119613
# Filtration: 1963
# filtration size 10012
# Filtration: 1964
# filtration size 27256
# Filtration: 1965
# filtration size 20035
# Filtration: 1966
# filtration size 99102
# Filtration: 1967
# filtration size 74862
# Filtration: 1968
# filtration size 23587
# Filtration: 1969
# filtration size 6165
# Filtration: 1970
# filtration size 109082
# Filtration: 1971
# filtration size 105461
# Filtration: 1972
# filtration size 120162
# Filtration: 1973
# filtration size 114884
# Filtration: 1974
# filtration size 113634
# Filtration: 1975
# filtration size 82757
# Filtration: 1976
# filtration size 36314
# Filtration: 1977
# filtration size 53620
# Filtration: 1978
# filtration size 133616
# Filtration: 1979
# filtration size 13011
# Filtration: 1980
# filtration size 20519
# Filtration: 1981
# filtration size 67417
# Filtration: 1982
# filtration size 67511
# Filtration: 1983
# filtration size 125125
# Filtration: 1984
# filtration size 91867
# Filtration: 1985
# filtration size 6712
# Filtration: 1986
# filtration size 62801
# Filtration: 1987
# filtration size 130127
# Filtration: 1988
# filtration size 124645
# Filtration: 1989
# filtration size 111163
# Filtration: 1990
# filtration size 132268
# Filtration: 1991
# filtration size 135743
# Filtration: 1992
# filtration size 16305
# Filtration: 1993
# filtration size 80438
# Filtration: 1994
# filtration size 83166
# Filtration: 1995
# filtration size 127278
# Filtration: 1996
# filtration size 125606
# Filtration: 1997
# filtration size 88284
# Filtration: 1998
# filtration size 13521
# Filtration: 1999
# filtration size 34587

# %%
adv_df, adv_sample_graphs, adv_dgms, adv_lifetimes = create_adversary_subgraphs(model, 1, 2000, adversaries)
# Out:
# torch.Size([4116, 1, 28, 28]) torch.Size([4116])
# Filtration: 0
# filtration size 9572
# Filtration: 1
# filtration size 77275
# Filtration: 2
# filtration size 144309
# Filtration: 3
# filtration size 7828
# Filtration: 4
# filtration size 91744
# Filtration: 5
# filtration size 106766
# Filtration: 6
# filtration size 59808
# Filtration: 7
# filtration size 67517
# Filtration: 8
# filtration size 14605
# Filtration: 9
# filtration size 12070
# Filtration: 10
# filtration size 96467
# Filtration: 11
# filtration size 103369
# Filtration: 12
# filtration size 86325
# Filtration: 13
# filtration size 90960
# Filtration: 14
# filtration size 38112
# Filtration: 15
# filtration size 38112
# Filtration: 16
# filtration size 23850
# Filtration: 17
# filtration size 24735
# Filtration: 18
# filtration size 123275
# Filtration: 19
# filtration size 74575
# Filtration: 20
# filtration size 93178
# Filtration: 21
# filtration size 23435
# Filtration: 22
# filtration size 17658
# Filtration: 23
# filtration size 34051
# Filtration: 24
# filtration size 16904
# Filtration: 25
# filtration size 39812
# Filtration: 26
# filtration size 36701
# Filtration: 27
# filtration size 34126
# Filtration: 28
# filtration size 82469
# Filtration: 29
# filtration size 81515
# Filtration: 30
# filtration size 30624
# Filtration: 31
# filtration size 41307
# Filtration: 32
# filtration size 63195
# Filtration: 33
# filtration size 65198
# Filtration: 34
# filtration size 106440
# Filtration: 35
# filtration size 80137
# Filtration: 36
# filtration size 119610
# Filtration: 37
# filtration size 117739
# Filtration: 38
# filtration size 37484
# Filtration: 39
# filtration size 31897
# Filtration: 40
# filtration size 80189
# Filtration: 41
# filtration size 52214
# Filtration: 42
# filtration size 118158
# Filtration: 43
# filtration size 94605
# Filtration: 44
# filtration size 60454
# Filtration: 45
# filtration size 29305
# Filtration: 46
# filtration size 15201
# Filtration: 47
# filtration size 110869
# Filtration: 48
# filtration size 132595
# Filtration: 49
# filtration size 21494
# Filtration: 50
# filtration size 57034
# Filtration: 51
# filtration size 53218
# Filtration: 52
# filtration size 43329
# Filtration: 53
# filtration size 105384
# Filtration: 54
# filtration size 71091
# Filtration: 55
# filtration size 138891
# Filtration: 56
# filtration size 138891
# Filtration: 57
# filtration size 72010
# Filtration: 58
# filtration size 84011
# Filtration: 59
# filtration size 88181
# Filtration: 60
# filtration size 32511
# Filtration: 61
# filtration size 39640
# Filtration: 62
# filtration size 134877
# Filtration: 63
# filtration size 100816
# Filtration: 64
# filtration size 100814
# Filtration: 65
# filtration size 6620
# Filtration: 66
# filtration size 17730
# Filtration: 67
# filtration size 53207
# Filtration: 68
# filtration size 76976
# Filtration: 69
# filtration size 40057
# Filtration: 70
# filtration size 104908
# Filtration: 71
# filtration size 60747
# Filtration: 72
# filtration size 71707
# Filtration: 73
# filtration size 34610
# Filtration: 74
# filtration size 91554
# Filtration: 75
# filtration size 94459
# Filtration: 76
# filtration size 14499
# Filtration: 77
# filtration size 90132
# Filtration: 78
# filtration size 90321
# Filtration: 79
# filtration size 93544
# Filtration: 80
# filtration size 125522
# Filtration: 81
# filtration size 124052
# Filtration: 82
# filtration size 44800
# Filtration: 83
# filtration size 63655
# Filtration: 84
# filtration size 117578
# Filtration: 85
# filtration size 53382
# Filtration: 86
# filtration size 47077
# Filtration: 87
# filtration size 69236
# Filtration: 88
# filtration size 36066
# Filtration: 89
# filtration size 138179
# Filtration: 90
# filtration size 76406
# Filtration: 91
# filtration size 79593
# Filtration: 92
# filtration size 99797
# Filtration: 93
# filtration size 96164
# Filtration: 94
# filtration size 18323
# Filtration: 95
# filtration size 12981
# Filtration: 96
# filtration size 24034
# Filtration: 97
# filtration size 25942
# Filtration: 98
# filtration size 10280
# Filtration: 99
# filtration size 9598
# Filtration: 100
# filtration size 119677
# Filtration: 101
# filtration size 43300
# Filtration: 102
# filtration size 18574
# Filtration: 103
# filtration size 18574
# Filtration: 104
# filtration size 80317
# Filtration: 105
# filtration size 94433
# Filtration: 106
# filtration size 83216
# Filtration: 107
# filtration size 21614
# Filtration: 108
# filtration size 20813
# Filtration: 109
# filtration size 110551
# Filtration: 110
# filtration size 41490
# Filtration: 111
# filtration size 79158
# Filtration: 112
# filtration size 46970
# Filtration: 113
# filtration size 125090
# Filtration: 114
# filtration size 114230
# Filtration: 115
# filtration size 8007
# Filtration: 116
# filtration size 97061
# Filtration: 117
# filtration size 136798
# Filtration: 118
# filtration size 137675
# Filtration: 119
# filtration size 133301
# Filtration: 120
# filtration size 30658
# Filtration: 121
# filtration size 32162
# Filtration: 122
# filtration size 63287
# Filtration: 123
# filtration size 90809
# Filtration: 124
# filtration size 32875
# Filtration: 125
# filtration size 45362
# Filtration: 126
# filtration size 96211
# Filtration: 127
# filtration size 93647
# Filtration: 128
# filtration size 48671
# Filtration: 129
# filtration size 56631
# Filtration: 130
# filtration size 11925
# Filtration: 131
# filtration size 56521
# Filtration: 132
# filtration size 44728
# Filtration: 133
# filtration size 86064
# Filtration: 134
# filtration size 88427
# Filtration: 135
# filtration size 93030
# Filtration: 136
# filtration size 123069
# Filtration: 137
# filtration size 112469
# Filtration: 138
# filtration size 99928
# Filtration: 139
# filtration size 29524
# Filtration: 140
# filtration size 118623
# Filtration: 141
# filtration size 63989
# Filtration: 142
# filtration size 80093
# Filtration: 143
# filtration size 77796
# Filtration: 144
# filtration size 108845
# Filtration: 145
# filtration size 142053
# Filtration: 146
# filtration size 16183
# Filtration: 147
# filtration size 34539
# Filtration: 148
# filtration size 107305
# Filtration: 149
# filtration size 125437
# Filtration: 150
# filtration size 115810
# Filtration: 151
# filtration size 9121
# Filtration: 152
# filtration size 7690
# Filtration: 153
# filtration size 30260
# Filtration: 154
# filtration size 18647
# Filtration: 155
# filtration size 125798
# Filtration: 156
# filtration size 42121
# Filtration: 157
# filtration size 45907
# Filtration: 158
# filtration size 80382
# Filtration: 159
# filtration size 90432
# Filtration: 160
# filtration size 12849
# Filtration: 161
# filtration size 16047
# Filtration: 162
# filtration size 116457
# Filtration: 163
# filtration size 82330
# Filtration: 164
# filtration size 56916
# Filtration: 165
# filtration size 76724
# Filtration: 166
# filtration size 61264
# Filtration: 167
# filtration size 76782
# Filtration: 168
# filtration size 99365
# Filtration: 169
# filtration size 129173
# Filtration: 170
# filtration size 68393
# Filtration: 171
# filtration size 59551
# Filtration: 172
# filtration size 15021
# Filtration: 173
# filtration size 24636
# Filtration: 174
# filtration size 137606
# Filtration: 175
# filtration size 9597
# Filtration: 176
# filtration size 17532
# Filtration: 177
# filtration size 103410
# Filtration: 178
# filtration size 103158
# Filtration: 179
# filtration size 15192
# Filtration: 180
# filtration size 27878
# Filtration: 181
# filtration size 80061
# Filtration: 182
# filtration size 30319
# Filtration: 183
# filtration size 36454
# Filtration: 184
# filtration size 22483
# Filtration: 185
# filtration size 87890
# Filtration: 186
# filtration size 45318
# Filtration: 187
# filtration size 31690
# Filtration: 188
# filtration size 14741
# Filtration: 189
# filtration size 15776
# Filtration: 190
# filtration size 11572
# Filtration: 191
# filtration size 32594
# Filtration: 192
# filtration size 67261
# Filtration: 193
# filtration size 30734
# Filtration: 194
# filtration size 42414
# Filtration: 195
# filtration size 11299
# Filtration: 196
# filtration size 14263
# Filtration: 197
# filtration size 15756
# Filtration: 198
# filtration size 11018
# Filtration: 199
# filtration size 74382
# Filtration: 200
# filtration size 22789
# Filtration: 201
# filtration size 19861
# Filtration: 202
# filtration size 113858
# Filtration: 203
# filtration size 47908
# Filtration: 204
# filtration size 25821
# Filtration: 205
# filtration size 98616
# Filtration: 206
# filtration size 98616
# Filtration: 207
# filtration size 80757
# Filtration: 208
# filtration size 88828
# Filtration: 209
# filtration size 145571
# Filtration: 210
# filtration size 8480
# Filtration: 211
# filtration size 58924
# Filtration: 212
# filtration size 53518
# Filtration: 213
# filtration size 10320
# Filtration: 214
# filtration size 79661
# Filtration: 215
# filtration size 90322
# Filtration: 216
# filtration size 75182
# Filtration: 217
# filtration size 107790
# Filtration: 218
# filtration size 90805
# Filtration: 219
# filtration size 18659
# Filtration: 220
# filtration size 14130
# Filtration: 221
# filtration size 26154
# Filtration: 222
# filtration size 102148
# Filtration: 223
# filtration size 95256
# Filtration: 224
# filtration size 91536
# Filtration: 225
# filtration size 51031
# Filtration: 226
# filtration size 119688
# Filtration: 227
# filtration size 27293
# Filtration: 228
# filtration size 28614
# Filtration: 229
# filtration size 19037
# Filtration: 230
# filtration size 41813
# Filtration: 231
# filtration size 111424
# Filtration: 232
# filtration size 135032
# Filtration: 233
# filtration size 8808
# Filtration: 234
# filtration size 17420
# Filtration: 235
# filtration size 14909
# Filtration: 236
# filtration size 18033
# Filtration: 237
# filtration size 40934
# Filtration: 238
# filtration size 22776
# Filtration: 239
# filtration size 30700
# Filtration: 240
# filtration size 137890
# Filtration: 241
# filtration size 110439
# Filtration: 242
# filtration size 123399
# Filtration: 243
# filtration size 94019
# Filtration: 244
# filtration size 94551
# Filtration: 245
# filtration size 83746
# Filtration: 246
# filtration size 64022
# Filtration: 247
# filtration size 115575
# Filtration: 248
# filtration size 15387
# Filtration: 249
# filtration size 41601
# Filtration: 250
# filtration size 49115
# Filtration: 251
# filtration size 45277
# Filtration: 252
# filtration size 28641
# Filtration: 253
# filtration size 38962
# Filtration: 254
# filtration size 142231
# Filtration: 255
# filtration size 144888
# Filtration: 256
# filtration size 21489
# Filtration: 257
# filtration size 25527
# Filtration: 258
# filtration size 108777
# Filtration: 259
# filtration size 13992
# Filtration: 260
# filtration size 11462
# Filtration: 261
# filtration size 46280
# Filtration: 262
# filtration size 134023
# Filtration: 263
# filtration size 86348
# Filtration: 264
# filtration size 135112
# Filtration: 265
# filtration size 127168
# Filtration: 266
# filtration size 100682
# Filtration: 267
# filtration size 99537
# Filtration: 268
# filtration size 102507
# Filtration: 269
# filtration size 8786
# Filtration: 270
# filtration size 7874
# Filtration: 271
# filtration size 34241
# Filtration: 272
# filtration size 34550
# Filtration: 273
# filtration size 77101
# Filtration: 274
# filtration size 11585
# Filtration: 275
# filtration size 67491
# Filtration: 276
# filtration size 70385
# Filtration: 277
# filtration size 27434
# Filtration: 278
# filtration size 44239
# Filtration: 279
# filtration size 87562
# Filtration: 280
# filtration size 146419
# Filtration: 281
# filtration size 70080
# Filtration: 282
# filtration size 70593
# Filtration: 283
# filtration size 68258
# Filtration: 284
# filtration size 66275
# Filtration: 285
# filtration size 31608
# Filtration: 286
# filtration size 9170
# Filtration: 287
# filtration size 34021
# Filtration: 288
# filtration size 36693
# Filtration: 289
# filtration size 16475
# Filtration: 290
# filtration size 68658
# Filtration: 291
# filtration size 42609
# Filtration: 292
# filtration size 38473
# Filtration: 293
# filtration size 106550
# Filtration: 294
# filtration size 119532
# Filtration: 295
# filtration size 15984
# Filtration: 296
# filtration size 31089
# Filtration: 297
# filtration size 135026
# Filtration: 298
# filtration size 68124
# Filtration: 299
# filtration size 66685
# Filtration: 300
# filtration size 28439
# Filtration: 301
# filtration size 28439
# Filtration: 302
# filtration size 137709
# Filtration: 303
# filtration size 64910
# Filtration: 304
# filtration size 131875
# Filtration: 305
# filtration size 24055
# Filtration: 306
# filtration size 29809
# Filtration: 307
# filtration size 61124
# Filtration: 308
# filtration size 130355
# Filtration: 309
# filtration size 124372
# Filtration: 310
# filtration size 88458
# Filtration: 311
# filtration size 91440
# Filtration: 312
# filtration size 113896
# Filtration: 313
# filtration size 75101
# Filtration: 314
# filtration size 39452
# Filtration: 315
# filtration size 78253
# Filtration: 316
# filtration size 127986
# Filtration: 317
# filtration size 142529
# Filtration: 318
# filtration size 6740
# Filtration: 319
# filtration size 12089
# Filtration: 320
# filtration size 7296
# Filtration: 321
# filtration size 79095
# Filtration: 322
# filtration size 73805
# Filtration: 323
# filtration size 38372
# Filtration: 324
# filtration size 59878
# Filtration: 325
# filtration size 101264
# Filtration: 326
# filtration size 97800
# Filtration: 327
# filtration size 15786
# Filtration: 328
# filtration size 103210
# Filtration: 329
# filtration size 72230
# Filtration: 330
# filtration size 45234
# Filtration: 331
# filtration size 81350
# Filtration: 332
# filtration size 94290
# Filtration: 333
# filtration size 69984
# Filtration: 334
# filtration size 18361
# Filtration: 335
# filtration size 125259
# Filtration: 336
# filtration size 103104
# Filtration: 337
# filtration size 135741
# Filtration: 338
# filtration size 83291
# Filtration: 339
# filtration size 28379
# Filtration: 340
# filtration size 4648
# Filtration: 341
# filtration size 83217
# Filtration: 342
# filtration size 48311
# Filtration: 343
# filtration size 5933
# Filtration: 344
# filtration size 7597
# Filtration: 345
# filtration size 64384
# Filtration: 346
# filtration size 23432
# Filtration: 347
# filtration size 52461
# Filtration: 348
# filtration size 132779
# Filtration: 349
# filtration size 58008
# Filtration: 350
# filtration size 77799
# Filtration: 351
# filtration size 22715
# Filtration: 352
# filtration size 127463
# Filtration: 353
# filtration size 116785
# Filtration: 354
# filtration size 55391
# Filtration: 355
# filtration size 20189
# Filtration: 356
# filtration size 106359
# Filtration: 357
# filtration size 46940
# Filtration: 358
# filtration size 23774
# Filtration: 359
# filtration size 58295
# Filtration: 360
# filtration size 65780
# Filtration: 361
# filtration size 63834
# Filtration: 362
# filtration size 137211
# Filtration: 363
# filtration size 114162
# Filtration: 364
# filtration size 94319
# Filtration: 365
# filtration size 57125
# Filtration: 366
# filtration size 51849
# Filtration: 367
# filtration size 20498
# Filtration: 368
# filtration size 33369
# Filtration: 369
# filtration size 18880
# Filtration: 370
# filtration size 54003
# Filtration: 371
# filtration size 115945
# Filtration: 372
# filtration size 76002
# Filtration: 373
# filtration size 119187
# Filtration: 374
# filtration size 140506
# Filtration: 375
# filtration size 81269
# Filtration: 376
# filtration size 22309
# Filtration: 377
# filtration size 30976
# Filtration: 378
# filtration size 52815
# Filtration: 379
# filtration size 99404
# Filtration: 380
# filtration size 104233
# Filtration: 381
# filtration size 41071
# Filtration: 382
# filtration size 109567
# Filtration: 383
# filtration size 48256
# Filtration: 384
# filtration size 123774
# Filtration: 385
# filtration size 124492
# Filtration: 386
# filtration size 38144
# Filtration: 387
# filtration size 70321
# Filtration: 388
# filtration size 20106
# Filtration: 389
# filtration size 113158
# Filtration: 390
# filtration size 124199
# Filtration: 391
# filtration size 13515
# Filtration: 392
# filtration size 11153
# Filtration: 393
# filtration size 32956
# Filtration: 394
# filtration size 65628
# Filtration: 395
# filtration size 16720
# Filtration: 396
# filtration size 90169
# Filtration: 397
# filtration size 33003
# Filtration: 398
# filtration size 16517
# Filtration: 399
# filtration size 7360
# Filtration: 400
# filtration size 25576
# Filtration: 401
# filtration size 133772
# Filtration: 402
# filtration size 128945
# Filtration: 403
# filtration size 117700
# Filtration: 404
# filtration size 11988
# Filtration: 405
# filtration size 95837
# Filtration: 406
# filtration size 82940
# Filtration: 407
# filtration size 146867
# Filtration: 408
# filtration size 16179
# Filtration: 409
# filtration size 106285
# Filtration: 410
# filtration size 88643
# Filtration: 411
# filtration size 95560
# Filtration: 412
# filtration size 125532
# Filtration: 413
# filtration size 116471
# Filtration: 414
# filtration size 136790
# Filtration: 415
# filtration size 36662
# Filtration: 416
# filtration size 26319
# Filtration: 417
# filtration size 59540
# Filtration: 418
# filtration size 13022
# Filtration: 419
# filtration size 110286
# Filtration: 420
# filtration size 68774
# Filtration: 421
# filtration size 118682
# Filtration: 422
# filtration size 110296
# Filtration: 423
# filtration size 55937
# Filtration: 424
# filtration size 66872
# Filtration: 425
# filtration size 63026
# Filtration: 426
# filtration size 101613
# Filtration: 427
# filtration size 138748
# Filtration: 428
# filtration size 94394
# Filtration: 429
# filtration size 69337
# Filtration: 430
# filtration size 14087
# Filtration: 431
# filtration size 66170
# Filtration: 432
# filtration size 30929
# Filtration: 433
# filtration size 40094
# Filtration: 434
# filtration size 138588
# Filtration: 435
# filtration size 111512
# Filtration: 436
# filtration size 87319
# Filtration: 437
# filtration size 34608
# Filtration: 438
# filtration size 75584
# Filtration: 439
# filtration size 41545
# Filtration: 440
# filtration size 6571
# Filtration: 441
# filtration size 16875
# Filtration: 442
# filtration size 132455
# Filtration: 443
# filtration size 79261
# Filtration: 444
# filtration size 24152
# Filtration: 445
# filtration size 20321
# Filtration: 446
# filtration size 20982
# Filtration: 447
# filtration size 58463
# Filtration: 448
# filtration size 19873
# Filtration: 449
# filtration size 72123
# Filtration: 450
# filtration size 118675
# Filtration: 451
# filtration size 45121
# Filtration: 452
# filtration size 62105
# Filtration: 453
# filtration size 49074
# Filtration: 454
# filtration size 80433
# Filtration: 455
# filtration size 122782
# Filtration: 456
# filtration size 31356
# Filtration: 457
# filtration size 82117
# Filtration: 458
# filtration size 16108
# Filtration: 459
# filtration size 122032
# Filtration: 460
# filtration size 87341
# Filtration: 461
# filtration size 34570
# Filtration: 462
# filtration size 41234
# Filtration: 463
# filtration size 28328
# Filtration: 464
# filtration size 15147
# Filtration: 465
# filtration size 117399
# Filtration: 466
# filtration size 72508
# Filtration: 467
# filtration size 96980
# Filtration: 468
# filtration size 126736
# Filtration: 469
# filtration size 47726
# Filtration: 470
# filtration size 8117
# Filtration: 471
# filtration size 25977
# Filtration: 472
# filtration size 121942
# Filtration: 473
# filtration size 18487
# Filtration: 474
# filtration size 118409
# Filtration: 475
# filtration size 29697
# Filtration: 476
# filtration size 126135
# Filtration: 477
# filtration size 97878
# Filtration: 478
# filtration size 124171
# Filtration: 479
# filtration size 133199
# Filtration: 480
# filtration size 27042
# Filtration: 481
# filtration size 69508
# Filtration: 482
# filtration size 9706
# Filtration: 483
# filtration size 63653
# Filtration: 484
# filtration size 132265
# Filtration: 485
# filtration size 114970
# Filtration: 486
# filtration size 124677
# Filtration: 487
# filtration size 125690
# Filtration: 488
# filtration size 135730
# Filtration: 489
# filtration size 41051
# Filtration: 490
# filtration size 49337
# Filtration: 491
# filtration size 21187
# Filtration: 492
# filtration size 33997
# Filtration: 493
# filtration size 16527
# Filtration: 494
# filtration size 9865
# Filtration: 495
# filtration size 51252
# Filtration: 496
# filtration size 85294
# Filtration: 497
# filtration size 115197
# Filtration: 498
# filtration size 56580
# Filtration: 499
# filtration size 42259
# Filtration: 500
# filtration size 102304
# Filtration: 501
# filtration size 6422
# Filtration: 502
# filtration size 40627
# Filtration: 503
# filtration size 90460
# Filtration: 504
# filtration size 7137
# Filtration: 505
# filtration size 113963
# Filtration: 506
# filtration size 136919
# Filtration: 507
# filtration size 24680
# Filtration: 508
# filtration size 90446
# Filtration: 509
# filtration size 38548
# Filtration: 510
# filtration size 8878
# Filtration: 511
# filtration size 74081
# Filtration: 512
# filtration size 99879
# Filtration: 513
# filtration size 89610
# Filtration: 514
# filtration size 68827
# Filtration: 515
# filtration size 62642
# Filtration: 516
# filtration size 85925
# Filtration: 517
# filtration size 58271
# Filtration: 518
# filtration size 95340
# Filtration: 519
# filtration size 4971
# Filtration: 520
# filtration size 8014
# Filtration: 521
# filtration size 131828
# Filtration: 522
# filtration size 118953
# Filtration: 523
# filtration size 126267
# Filtration: 524
# filtration size 140765
# Filtration: 525
# filtration size 14832
# Filtration: 526
# filtration size 86946
# Filtration: 527
# filtration size 53540
# Filtration: 528
# filtration size 120152
# Filtration: 529
# filtration size 93493
# Filtration: 530
# filtration size 79185
# Filtration: 531
# filtration size 74640
# Filtration: 532
# filtration size 21748
# Filtration: 533
# filtration size 66083
# Filtration: 534
# filtration size 122161
# Filtration: 535
# filtration size 12856
# Filtration: 536
# filtration size 42610
# Filtration: 537
# filtration size 103101
# Filtration: 538
# filtration size 90209
# Filtration: 539
# filtration size 127767
# Filtration: 540
# filtration size 107640
# Filtration: 541
# filtration size 88213
# Filtration: 542
# filtration size 58243
# Filtration: 543
# filtration size 16135
# Filtration: 544
# filtration size 9656
# Filtration: 545
# filtration size 52147
# Filtration: 546
# filtration size 10938
# Filtration: 547
# filtration size 105190
# Filtration: 548
# filtration size 40009
# Filtration: 549
# filtration size 31779
# Filtration: 550
# filtration size 16747
# Filtration: 551
# filtration size 31279
# Filtration: 552
# filtration size 8921
# Filtration: 553
# filtration size 116721
# Filtration: 554
# filtration size 63606
# Filtration: 555
# filtration size 35571
# Filtration: 556
# filtration size 123771
# Filtration: 557
# filtration size 87338
# Filtration: 558
# filtration size 72969
# Filtration: 559
# filtration size 7160
# Filtration: 560
# filtration size 62343
# Filtration: 561
# filtration size 118393
# Filtration: 562
# filtration size 124029
# Filtration: 563
# filtration size 41501
# Filtration: 564
# filtration size 9719
# Filtration: 565
# filtration size 114017
# Filtration: 566
# filtration size 61255
# Filtration: 567
# filtration size 101939
# Filtration: 568
# filtration size 117791
# Filtration: 569
# filtration size 129613
# Filtration: 570
# filtration size 19682
# Filtration: 571
# filtration size 12332
# Filtration: 572
# filtration size 17120
# Filtration: 573
# filtration size 58360
# Filtration: 574
# filtration size 43931
# Filtration: 575
# filtration size 82968
# Filtration: 576
# filtration size 33489
# Filtration: 577
# filtration size 136841
# Filtration: 578
# filtration size 135407
# Filtration: 579
# filtration size 133785
# Filtration: 580
# filtration size 49090
# Filtration: 581
# filtration size 105622
# Filtration: 582
# filtration size 24639
# Filtration: 583
# filtration size 44976
# Filtration: 584
# filtration size 53883
# Filtration: 585
# filtration size 61135
# Filtration: 586
# filtration size 71888
# Filtration: 587
# filtration size 54205
# Filtration: 588
# filtration size 140527
# Filtration: 589
# filtration size 16491
# Filtration: 590
# filtration size 22699
# Filtration: 591
# filtration size 133611
# Filtration: 592
# filtration size 19297
# Filtration: 593
# filtration size 95788
# Filtration: 594
# filtration size 82610
# Filtration: 595
# filtration size 40922
# Filtration: 596
# filtration size 7602
# Filtration: 597
# filtration size 76023
# Filtration: 598
# filtration size 62782
# Filtration: 599
# filtration size 6828
# Filtration: 600
# filtration size 57978
# Filtration: 601
# filtration size 41889
# Filtration: 602
# filtration size 42671
# Filtration: 603
# filtration size 90041
# Filtration: 604
# filtration size 93344
# Filtration: 605
# filtration size 7690
# Filtration: 606
# filtration size 141798
# Filtration: 607
# filtration size 46839
# Filtration: 608
# filtration size 99002
# Filtration: 609
# filtration size 139254
# Filtration: 610
# filtration size 15940
# Filtration: 611
# filtration size 97789
# Filtration: 612
# filtration size 57841
# Filtration: 613
# filtration size 70176
# Filtration: 614
# filtration size 13073
# Filtration: 615
# filtration size 71532
# Filtration: 616
# filtration size 75634
# Filtration: 617
# filtration size 119713
# Filtration: 618
# filtration size 7266
# Filtration: 619
# filtration size 143608
# Filtration: 620
# filtration size 30521
# Filtration: 621
# filtration size 102082
# Filtration: 622
# filtration size 6308
# Filtration: 623
# filtration size 59226
# Filtration: 624
# filtration size 52564
# Filtration: 625
# filtration size 14495
# Filtration: 626
# filtration size 33842
# Filtration: 627
# filtration size 15005
# Filtration: 628
# filtration size 65511
# Filtration: 629
# filtration size 123847
# Filtration: 630
# filtration size 139194
# Filtration: 631
# filtration size 70332
# Filtration: 632
# filtration size 117844
# Filtration: 633
# filtration size 33459
# Filtration: 634
# filtration size 28758
# Filtration: 635
# filtration size 47777
# Filtration: 636
# filtration size 60581
# Filtration: 637
# filtration size 57617
# Filtration: 638
# filtration size 38723
# Filtration: 639
# filtration size 60168
# Filtration: 640
# filtration size 54726
# Filtration: 641
# filtration size 128953
# Filtration: 642
# filtration size 125167
# Filtration: 643
# filtration size 134611
# Filtration: 644
# filtration size 27916
# Filtration: 645
# filtration size 19631
# Filtration: 646
# filtration size 68768
# Filtration: 647
# filtration size 108353
# Filtration: 648
# filtration size 17688
# Filtration: 649
# filtration size 89026
# Filtration: 650
# filtration size 132368
# Filtration: 651
# filtration size 48655
# Filtration: 652
# filtration size 96250
# Filtration: 653
# filtration size 31896
# Filtration: 654
# filtration size 14610
# Filtration: 655
# filtration size 114839
# Filtration: 656
# filtration size 56060
# Filtration: 657
# filtration size 79514
# Filtration: 658
# filtration size 92117
# Filtration: 659
# filtration size 73569
# Filtration: 660
# filtration size 118370
# Filtration: 661
# filtration size 58086
# Filtration: 662
# filtration size 81482
# Filtration: 663
# filtration size 110018
# Filtration: 664
# filtration size 54364
# Filtration: 665
# filtration size 144884
# Filtration: 666
# filtration size 34819
# Filtration: 667
# filtration size 67021
# Filtration: 668
# filtration size 13085
# Filtration: 669
# filtration size 113525
# Filtration: 670
# filtration size 62008
# Filtration: 671
# filtration size 6817
# Filtration: 672
# filtration size 138007
# Filtration: 673
# filtration size 122541
# Filtration: 674
# filtration size 34467
# Filtration: 675
# filtration size 144429
# Filtration: 676
# filtration size 17974
# Filtration: 677
# filtration size 124729
# Filtration: 678
# filtration size 25002
# Filtration: 679
# filtration size 6610
# Filtration: 680
# filtration size 10410
# Filtration: 681
# filtration size 95979
# Filtration: 682
# filtration size 33828
# Filtration: 683
# filtration size 13318
# Filtration: 684
# filtration size 133487
# Filtration: 685
# filtration size 105971
# Filtration: 686
# filtration size 113489
# Filtration: 687
# filtration size 14032
# Filtration: 688
# filtration size 12041
# Filtration: 689
# filtration size 128160
# Filtration: 690
# filtration size 104066
# Filtration: 691
# filtration size 51496
# Filtration: 692
# filtration size 60084
# Filtration: 693
# filtration size 29330
# Filtration: 694
# filtration size 47079
# Filtration: 695
# filtration size 15729
# Filtration: 696
# filtration size 57792
# Filtration: 697
# filtration size 124383
# Filtration: 698
# filtration size 114009
# Filtration: 699
# filtration size 49856
# Filtration: 700
# filtration size 61309
# Filtration: 701
# filtration size 102174
# Filtration: 702
# filtration size 65071
# Filtration: 703
# filtration size 44629
# Filtration: 704
# filtration size 99678
# Filtration: 705
# filtration size 93465
# Filtration: 706
# filtration size 132331
# Filtration: 707
# filtration size 122680
# Filtration: 708
# filtration size 116097
# Filtration: 709
# filtration size 97492
# Filtration: 710
# filtration size 118406
# Filtration: 711
# filtration size 62905
# Filtration: 712
# filtration size 19236
# Filtration: 713
# filtration size 121141
# Filtration: 714
# filtration size 102101
# Filtration: 715
# filtration size 50712
# Filtration: 716
# filtration size 66152
# Filtration: 717
# filtration size 15624
# Filtration: 718
# filtration size 143745
# Filtration: 719
# filtration size 13125
# Filtration: 720
# filtration size 14152
# Filtration: 721
# filtration size 19534
# Filtration: 722
# filtration size 114301
# Filtration: 723
# filtration size 48861
# Filtration: 724
# filtration size 116768
# Filtration: 725
# filtration size 48291
# Filtration: 726
# filtration size 89487
# Filtration: 727
# filtration size 118131
# Filtration: 728
# filtration size 134701
# Filtration: 729
# filtration size 10859
# Filtration: 730
# filtration size 38579
# Filtration: 731
# filtration size 27807
# Filtration: 732
# filtration size 98658
# Filtration: 733
# filtration size 116224
# Filtration: 734
# filtration size 27195
# Filtration: 735
# filtration size 111626
# Filtration: 736
# filtration size 134346
# Filtration: 737
# filtration size 28161
# Filtration: 738
# filtration size 24909
# Filtration: 739
# filtration size 89871
# Filtration: 740
# filtration size 79372
# Filtration: 741
# filtration size 99390
# Filtration: 742
# filtration size 35282
# Filtration: 743
# filtration size 35870
# Filtration: 744
# filtration size 82749
# Filtration: 745
# filtration size 119195
# Filtration: 746
# filtration size 34373
# Filtration: 747
# filtration size 41664
# Filtration: 748
# filtration size 94972
# Filtration: 749
# filtration size 132346
# Filtration: 750
# filtration size 101235
# Filtration: 751
# filtration size 102127
# Filtration: 752
# filtration size 18314
# Filtration: 753
# filtration size 40075
# Filtration: 754
# filtration size 33734
# Filtration: 755
# filtration size 18709
# Filtration: 756
# filtration size 80200
# Filtration: 757
# filtration size 99303
# Filtration: 758
# filtration size 137034
# Filtration: 759
# filtration size 114394
# Filtration: 760
# filtration size 111762
# Filtration: 761
# filtration size 99145
# Filtration: 762
# filtration size 59909
# Filtration: 763
# filtration size 52976
# Filtration: 764
# filtration size 106606
# Filtration: 765
# filtration size 84642
# Filtration: 766
# filtration size 27632
# Filtration: 767
# filtration size 123011
# Filtration: 768
# filtration size 25373
# Filtration: 769
# filtration size 72833
# Filtration: 770
# filtration size 117072
# Filtration: 771
# filtration size 128779
# Filtration: 772
# filtration size 139911
# Filtration: 773
# filtration size 104582
# Filtration: 774
# filtration size 146192
# Filtration: 775
# filtration size 75796
# Filtration: 776
# filtration size 15119
# Filtration: 777
# filtration size 23682
# Filtration: 778
# filtration size 37573
# Filtration: 779
# filtration size 13353
# Filtration: 780
# filtration size 69946
# Filtration: 781
# filtration size 143253
# Filtration: 782
# filtration size 79112
# Filtration: 783
# filtration size 58771
# Filtration: 784
# filtration size 40897
# Filtration: 785
# filtration size 55341
# Filtration: 786
# filtration size 12902
# Filtration: 787
# filtration size 114371
# Filtration: 788
# filtration size 8337
# Filtration: 789
# filtration size 24318
# Filtration: 790
# filtration size 77952
# Filtration: 791
# filtration size 15251
# Filtration: 792
# filtration size 11646
# Filtration: 793
# filtration size 123775
# Filtration: 794
# filtration size 18776
# Filtration: 795
# filtration size 112466
# Filtration: 796
# filtration size 126448
# Filtration: 797
# filtration size 69344
# Filtration: 798
# filtration size 25096
# Filtration: 799
# filtration size 44772
# Filtration: 800
# filtration size 108597
# Filtration: 801
# filtration size 6776
# Filtration: 802
# filtration size 98782
# Filtration: 803
# filtration size 32952
# Filtration: 804
# filtration size 34648
# Filtration: 805
# filtration size 37772
# Filtration: 806
# filtration size 125506
# Filtration: 807
# filtration size 109997
# Filtration: 808
# filtration size 20655
# Filtration: 809
# filtration size 16954
# Filtration: 810
# filtration size 84637
# Filtration: 811
# filtration size 26562
# Filtration: 812
# filtration size 21109
# Filtration: 813
# filtration size 14752
# Filtration: 814
# filtration size 31400
# Filtration: 815
# filtration size 28755
# Filtration: 816
# filtration size 52164
# Filtration: 817
# filtration size 115170
# Filtration: 818
# filtration size 60895
# Filtration: 819
# filtration size 51864
# Filtration: 820
# filtration size 126785
# Filtration: 821
# filtration size 92149
# Filtration: 822
# filtration size 122641
# Filtration: 823
# filtration size 47884
# Filtration: 824
# filtration size 110952
# Filtration: 825
# filtration size 61384
# Filtration: 826
# filtration size 117741
# Filtration: 827
# filtration size 55244
# Filtration: 828
# filtration size 25652
# Filtration: 829
# filtration size 111582
# Filtration: 830
# filtration size 54775
# Filtration: 831
# filtration size 115429
# Filtration: 832
# filtration size 13113
# Filtration: 833
# filtration size 94959
# Filtration: 834
# filtration size 27165
# Filtration: 835
# filtration size 97573
# Filtration: 836
# filtration size 118165
# Filtration: 837
# filtration size 91722
# Filtration: 838
# filtration size 106035
# Filtration: 839
# filtration size 78771
# Filtration: 840
# filtration size 110558
# Filtration: 841
# filtration size 8569
# Filtration: 842
# filtration size 109960
# Filtration: 843
# filtration size 55388
# Filtration: 844
# filtration size 90468
# Filtration: 845
# filtration size 127926
# Filtration: 846
# filtration size 98537
# Filtration: 847
# filtration size 137545
# Filtration: 848
# filtration size 146736
# Filtration: 849
# filtration size 96503
# Filtration: 850
# filtration size 33352
# Filtration: 851
# filtration size 8921
# Filtration: 852
# filtration size 101151
# Filtration: 853
# filtration size 144577
# Filtration: 854
# filtration size 130928
# Filtration: 855
# filtration size 54597
# Filtration: 856
# filtration size 113679
# Filtration: 857
# filtration size 36386
# Filtration: 858
# filtration size 128111
# Filtration: 859
# filtration size 109300
# Filtration: 860
# filtration size 127450
# Filtration: 861
# filtration size 15684
# Filtration: 862
# filtration size 120142
# Filtration: 863
# filtration size 102950
# Filtration: 864
# filtration size 20045
# Filtration: 865
# filtration size 7756
# Filtration: 866
# filtration size 87331
# Filtration: 867
# filtration size 83778
# Filtration: 868
# filtration size 29138
# Filtration: 869
# filtration size 113730
# Filtration: 870
# filtration size 8820
# Filtration: 871
# filtration size 21962
# Filtration: 872
# filtration size 100255
# Filtration: 873
# filtration size 42615
# Filtration: 874
# filtration size 37631
# Filtration: 875
# filtration size 77859
# Filtration: 876
# filtration size 20480
# Filtration: 877
# filtration size 7307
# Filtration: 878
# filtration size 141809
# Filtration: 879
# filtration size 130884
# Filtration: 880
# filtration size 136864
# Filtration: 881
# filtration size 49334
# Filtration: 882
# filtration size 108268
# Filtration: 883
# filtration size 7337
# Filtration: 884
# filtration size 12561
# Filtration: 885
# filtration size 70756
# Filtration: 886
# filtration size 22523
# Filtration: 887
# filtration size 114817
# Filtration: 888
# filtration size 60684
# Filtration: 889
# filtration size 46238
# Filtration: 890
# filtration size 40393
# Filtration: 891
# filtration size 100570
# Filtration: 892
# filtration size 100904
# Filtration: 893
# filtration size 103676
# Filtration: 894
# filtration size 117936
# Filtration: 895
# filtration size 11144
# Filtration: 896
# filtration size 73567
# Filtration: 897
# filtration size 45640
# Filtration: 898
# filtration size 96264
# Filtration: 899
# filtration size 14313
# Filtration: 900
# filtration size 75407
# Filtration: 901
# filtration size 70128
# Filtration: 902
# filtration size 17081
# Filtration: 903
# filtration size 103211
# Filtration: 904
# filtration size 17587
# Filtration: 905
# filtration size 7188
# Filtration: 906
# filtration size 68133
# Filtration: 907
# filtration size 9340
# Filtration: 908
# filtration size 142120
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-10-f0bc5034c58f> in <module>
# ----> 1 adv_df, adv_sample_graphs, adv_dgms, adv_lifetimes = create_adversary_subgraphs(model, 1, 2000, adversaries)
#
# <ipython-input-6-68d9f1da2182> in create_adversary_subgraphs(model, batch_size, up_to, adversaries)
#      66         for data, target in test_loader:
#      67             data, target = data.to(device), target.to(device)
# ---> 68             output, hiddens = model(data, hiddens=True)
#      69             test_loss = F.nll_loss(output, target).item() # sum up batch loss
#      70             pred = output.max(1, keepdim=True)[1] # get the index of the max log-probability
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/projects/pt_activation/pt_activation/models/cff_sigmoid.py in forward(self, x, hiddens)
#      27
#      28     def forward(self, x, hiddens=False):
# ---> 29         h1_m = F.sigmoid(self.conv1(x))
#      30         h1 = h1_m.view(-1, (28-self.kernel_size+1)**2*self.filters)
#      31         h2 = F.sigmoid(self.fc1(h1))
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/.local/lib/python3.6/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     318     def forward(self, input):
#     319         return F.conv2d(input, self.weight, self.bias, self.stride,
# --> 320                         self.padding, self.dilation, self.groups)
#     321
#     322
#
# RuntimeError: can't alloc

# %%
with open(os.path.join(adv_directory_loc, 'adv_samples.pkl'), 'wb') as f:
    pickle.dump(adv_sample_graphs, f)
with open(os.path.join(adv_directory_loc, 'samples.pkl'), 'wb') as f:
    pickle.dump(sample_graphs, f)

# sample_graphs = pickle.load( open(os.path.join(adv_directory_loc, 'samples.pkl'), "rb") )
# adv_sample_graphs = pickle.load( open(os.path.join(adv_directory_loc, 'adv_samples.pkl'), "rb") )

# %%
# for dgm in dgms:
#     dion.plot.plot_diagram(dgm, show=True)

# %%
# for adv_dgm in adv_dgms:
#     dion.plot.plot_diagram(adv_dgm, show=True)

# %%
# thru = 3
# all_gois = []
# for i in range(len(sample_graphs)):
#     print(i)
#     ks = list(sample_graphs[i].keys())
#     a = [sample_graphs[i][k] for k in ks[:thru]]
#     all_gois.append(nx.compose_all(a))
    
# adv_all_gois = []
# for i in range(len(adv_sample_graphs)):
#     print(i)
#     ks = list(adv_sample_graphs[i].keys())
#     a = [adv_sample_graphs[i][k] for k in ks[:thru]]
#     adv_all_gois.append(nx.compose_all(a))

# %%
def hamming_distance(g1, g2, ret_labels=False):
    nodeset = set(list(g1.nodes) + list(g2.nodes))
    g1_vec = np.zeros((len(nodeset)))
    g2_vec = np.zeros((len(nodeset)))
    nodesetlist = list(nodeset)
    for i in range(len(nodesetlist)):
        node = nodesetlist[i]
        if node in g1.nodes:
            g1_vec[i] = 1.0
        if node in g2.nodes:
            g2_vec[i] = 1.0
    if ret_labels:
        return hamming(g1_vec, g2_vec), nodesetlist
    else:
        return hamming(g1_vec, g2_vec)
    
def edge_hamming_distance(g1, g2, ret_labels=False):
    edgeset = set(list(g1.edges) + list(g2.edges))
    g1_vec = np.zeros((len(edgeset)))
    g2_vec = np.zeros((len(edgeset)))
    edgesetlist = list(edgeset)
    for i in range(len(edgesetlist)):
        edge = edgesetlist[i]
        if edge in g1.edges:
            g1_vec[i] = 1.0
        if edge in g2.edges:
            g2_vec[i] = 1.0
    if ret_labels:
        return hamming(g1_vec, g2_vec), edgesetlist
    else:
        return hamming(g1_vec, g2_vec)
    
def lifetime_weighted_edge_distance(subgraphs1,subgraphs2,lifetimes1,lifetimes2,ret_labels=False):
    edges1 = {}
    edges2 = {}
    sg1keys = list(subgraphs1.keys())
    sg2keys = list(subgraphs2.keys())
    lifetimes1 = list(lifetimes1.values())
    lifetimes2 = list(lifetimes2.values())
    ml1 = max(lifetimes1)
    ml2 = max(lifetimes2)
    for i in range(len(sg1keys)):
        g = subgraphs1[sg1keys[i]]
        for e in g.edges:
            edges1[e] = lifetimes1[i]/ml1
    for i in range(len(sg2keys)):
        g = subgraphs2[sg2keys[i]]
        for e in g.edges:
            edges2[e] = lifetimes2[i]/ml2
    edgeset = set(list(edges1.keys()) + list(edges2.keys()))
    g1_vec = np.zeros((len(edgeset)))
    g2_vec = np.zeros((len(edgeset)))
    edgesetlist = list(edgeset)
    for i in range(len(edgesetlist)):
        edge = edgesetlist[i]
        if edge in edges1:
            g1_vec[i] += edges1[edge]
        if edge in edges2:
            g2_vec[i] += edges2[edge]
    if ret_labels:
        return cosine(g1_vec, g2_vec), edgesetlist
    else:
        return cosine(g1_vec, g2_vec)
    
def weighted_edge_distance(g1, g2, ret_labels=False):
    edgeset = set(list(g1.edges) + list(g2.edges))
    g1_vec = np.zeros((len(edgeset)))
    g2_vec = np.zeros((len(edgeset)))
    edgesetlist = list(edgeset)
    for i in range(len(edgesetlist)):
        edge = edgesetlist[i]
        if edge in g1.edges:
            g1_vec[i] = g1[edge[0]][edge[1]]['weight']
        if edge in g2.edges:
            g2_vec[i] = g2[edge[0]][edge[1]]['weight']
    if ret_labels:
        return cosine(g1_vec, g2_vec), edgesetlist
    else:
        return cosine(g1_vec, g2_vec)
    
def compute_kernel_matrix(gs, ls, take=3):
    ret = np.zeros((len(gs),len(gs)))
    for i in range(len(gs)):
        print('row: ', i)
        g1 = gs[i]
        lt1 = ls[i]
        g1keys = list(g1.keys())
        g1 = {k: g1[k] for k in g1keys[:take]}
        for j in range(len(gs)):
            g2 = gs[j]
            lt2 = ls[j]
            g2keys = list(g2.keys())
            g2 = {k: g2[k] for k in g2keys[:take]}
            ret[i,j] = 1 - lifetime_weighted_edge_distance(g1,g2,lt1,lt2)
    return ret

# %%
gs = sample_graphs
ls = lifetimes

# %%
X = compute_kernel_matrix(gs, ls, take=-1)
y = res_df['class'].values

# %%
clf = svm.SVC(decision_function_shape='ovo', kernel='precomputed')
cross_val_score(clf, X, y, cv=10)

# %%
np.average(cross_val_score(clf, X, y, cv=10))

# %%
print('Natural performance: ', res_df[res_df['class'] == res_df['prediction']].shape[0]/res_df.shape[0])

# %%
take = 5
edges = set()
for i in range(len(sample_graphs)):
    for k in list(sample_graphs[i].keys())[:take]:
        for x in sample_graphs[i][k].edges(data=True):
            edge_name = str(x[0])+'-'+str(x[1])
            edges.add(edge_name)
            
edf = pd.DataFrame(np.zeros((len(sample_graphs),len(edges))), columns=list(edges))
for i in range(len(sample_graphs)):
    print('Sample: {}/{}'.format(i,len(sample_graphs)))
    lst = list(sample_graphs[i].keys())
    for k in lst[:take]:
        for x in sample_graphs[i][k].edges(data=True):
            edge_name = str(x[0])+'-'+str(x[1])
#             edf.iloc[i][edge_name] += x[2]['weight']
            edf.iloc[i][edge_name] += 1

# %%
edf.head()

# %%
kernel='linear'
X = edf.values
y = res_df['class'].values
clf = svm.SVC(decision_function_shape='ovo', kernel=kernel)
cvs = cross_val_score(clf, X, y, cv=10)

# %%
cvs.mean()

# %%
t_fit = svm.SVC(decision_function_shape='ovo', kernel=kernel).fit(X,y)

# %%
# take = 3
# adv_edges = set()
# for i in range(len(adv_sample_graphs)):
#     for k in list(adv_sample_graphs[i].keys())[:take]:
#         for x in adv_sample_graphs[i][k].edges(data=True):
#             edge_name = str(x[0])+'-'+str(x[1])
#             adv_edges.add(edge_name)

# %%
adv_edf = pd.DataFrame(np.zeros((len(sample_graphs),len(edges))), columns=list(edges))
for i in range(len(adv_sample_graphs)):
    print('Sample: {}/{}'.format(i,len(adv_sample_graphs)))
    lst = list(adv_sample_graphs[i].keys())
    for k in lst[:take]:
        for x in adv_sample_graphs[i][k].edges(data=True):
            edge_name = str(x[0])+'-'+str(x[1])
            if edge_name in adv_edf.columns:
                adv_edf.iloc[i][edge_name] += 10

# %%
adv_preds = t_fit.predict(adv_edf.values)

# %%
adv_preds[:5]

# %%
adv_df.head()

# %%
adv_df.shape

# %%
print('Recovery Accuracy: {}'.format(adv_df[adv_df['class'] == adv_preds[:adv_df.shape[0]]].shape[0]/adv_df.shape[0]))

# %%
print('Adversary Class Percentage: {}'.format(adv_df[adv_df['prediction'] == adv_preds].shape[0]/adv_df.shape[0]))

# %%
plt.imshow(adversaries[4]['adversary'].reshape(28,28))

# %%
adv_df['prediction'].value_counts()/adv_df.shape[0]

# %%
adv_df[adv_df['class'] == adv_preds]['prediction'].value_counts()/adv_df[adv_df['class'] == adv_preds]['prediction'].shape[0]

# %%
colors = ['black', 'blue', 'red', 'green', 'yellow', 'orange', 'purple', 'pink', 'silver', 'cyan']
labels = list(range(10))

# %%
# from sklearn.decomposition import PCA
# from mpl_toolkits.mplot3d import Axes3D
# import PyQt5

# fig = plt.figure(1, figsize=(4, 3))
# plt.clf()
# ax = Axes3D(fig)

# plt.cla()
# pca = PCA(n_components=3)
# pca.fit(X)
# X_pca = pca.transform(X)

# for i in range(len(X_pca)):
#     ax.scatter(X_pca[i,0], X_pca[i,1], X_pca[i,2], color=colors[res_df['prediction'].iloc[i]])

# %%
# from sklearn import manifold
# from collections import OrderedDict

# fig = plt.figure(1, figsize=(4, 3))
# plt.clf()
# ax = Axes3D(fig)
# plt.cla()

# # X_dimmed = manifold.TSNE(n_components=3, init='pca', random_state=0).fit_transform(X)
# X_dimmed = manifold.Isomap(10, 3).fit_transform(X)

# for i in range(len(X_dimmed)):
#     ax.scatter(X_dimmed[i,0], X_dimmed[i,1], X_dimmed[i,2], color=colors[res_df['class'].iloc[i]], label=labels[res_df['class'].iloc[i]])

# handles, labs = plt.gca().get_legend_handles_labels()
# by_label = OrderedDict(zip(labs, handles))
# ax.legend(by_label.values(), by_label.keys())

# %%
from sklearn.decomposition import PCA
from sklearn import manifold
from collections import OrderedDict
plot_take = 1000

# %%
fig, ax = plt.subplots()
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)

for i in range(len(X_pca)):
    ax.scatter(X_pca[i,0], X_pca[i,1], color=colors[res_df['prediction'].iloc[i]], label=labels[res_df['class'].iloc[i]])
handles, labs = plt.gca().get_legend_handles_labels()
by_label = OrderedDict(zip(labs, handles))
ax.legend(by_label.values(), by_label.keys())

# %%
from sklearn import manifold
fig, ax = plt.subplots()
X_dimmed = manifold.Isomap(n_neighbors=15, n_components=2).fit_transform(X)
# X_dimmed = manifold.TSNE(n_components=2, init='pca', random_state=5).fit_transform(X)
# X_dimmed = manifold.SpectralEmbedding(n_neighbors=100, n_components=2).fit_transform(X)
# X_dimmed = manifold.MDS(2, max_iter=200, n_init=10).fit_transform(X)
# X_dimmed = manifold.LocallyLinearEmbedding(10, 2, eigen_solver='auto', method='standard').fit_transform(X)


for i in range(len(X_dimmed)):
    ax.scatter(X_dimmed[i,0], X_dimmed[i,1], color=colors[res_df['prediction'].iloc[i]], label=labels[res_df['prediction'].iloc[i]])
handles, labs = plt.gca().get_legend_handles_labels()
by_label = OrderedDict(zip(labs, handles))
ax.legend(by_label.values(), by_label.keys())
